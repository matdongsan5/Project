# %%
from bs4 import BeautifulSoup
from urllib.request import Request
from urllib.parse import quote
from urllib.request import urlopen
from konlpy.tag import Okt
from collections import Counter
from wordcloud import WordCloud
import koreanize_matplotlib
import matplotlib.pyplot as plt
import platform
import numpy as np
from PIL import Image
import collections
import pandas as pd

# %%
import matplotlib.pyplot as plt
import numpy as np

colormaps = ['viridis', 'plasma', 'inferno', 'magma', 'cividis',
             'gray', 'Blues', 'cool', 'Reds', 'Oranges',
             'jet', 'rainbow', 'hsv', 'Spectral']

fig, axes = plt.subplots(len(colormaps), 1, figsize=(8, len(colormaps) * 0.5))

gradient = np.linspace(0, 1, 256).reshape(1, -1)

for ax, cmap in zip(axes, colormaps):
    ax.imshow(gradient, aspect='auto', cmap=cmap)
    ax.set_title(cmap, fontsize=10)
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout()
plt.show()

# %%
def make_wordcloud(word_list, stopwords, word_count,image1='cloud.png' ,colormap1 ='plasma' ):
    okt = Okt()
    nouns_list = list()
    for i in range(len(word_list)):
        nouns_list.extend(okt.nouns(word_list[i]))
    
    counts = Counter(nouns_list)
    tags = counts.most_common(word_count)
    tag_dict = dict(tags)
    # 검색어 제외 방법 : dict에서 해당 검색어 제거
    for stopword in stopwords:
        if stopword in tag_dict:
            tag_dict.pop(stopword)
            
    print('-' * 80)
    print('tag_dict:', tag_dict)
    if platform.system() == 'Windows':
        path = r'c:\Windows\Fonts\malgun.ttf'
    elif platform.system() == 'Darwin': # Mac OS
        path = r'/System/Library/Fonts/AppleGothic'
    else:
        path = r'/usr/share/fonts/truetype/name/NanumMyeongjo.ttf'
        
    img_mask = np.array(Image.open(image1))
    wordcloud = WordCloud(font_path=path, width=800,
                        height=600,
                        background_color="white",
                        max_font_size=200,
                        repeat=True,
                        colormap= colormap1,
                        mask=img_mask)
    
    cloud = wordcloud.generate_from_frequencies(tag_dict)
    
    plt.figure(figsize=(10, 8))
    plt.axis('off')
    plt.imshow(cloud)
    plt.show()

# %%
def make_wordcloud_ph(word_list, stopwords, word_count,image1='cloud.png' ,colormap1 ='plasma' ):
    okt = Okt()
    phrases_list = list()
    for i in range(len(word_list)):
        phrases_list.extend(okt.phrases(word_list[i]))
    
    counts = Counter(phrases_list)
    tags = counts.most_common(word_count)
    tag_dict = dict(tags)
    # 검색어 제외 방법 : dict에서 해당 검색어 제거
    for stopword in stopwords:
        if stopword in tag_dict:
            tag_dict.pop(stopword)
            
    print('-' * 80)
    print('tag_dict:', tag_dict)
    if platform.system() == 'Windows':
        path = r'c:\Windows\Fonts\malgun.ttf'
    elif platform.system() == 'Darwin': # Mac OS
        path = r'/System/Library/Fonts/AppleGothic'
    else:
        path = r'/usr/share/fonts/truetype/name/NanumMyeongjo.ttf'
        
    img_mask = np.array(Image.open(image1))
    wordcloud = WordCloud(font_path=path, width=800,
                        height=600,
                        background_color="white",
                        max_font_size=200,
                        repeat=True,
                        colormap= colormap1,
                        mask=img_mask)
    
    cloud = wordcloud.generate_from_frequencies(tag_dict)
    
    plt.figure(figsize=(10, 8))
    plt.axis('off')
    plt.imshow(cloud)
    plt.show()

# %%
def make_list(filepath, listname):
    with open(filepath, 'r') as file:
        for i in file:
            filter_list = i.replace('•',' ').replace('-',' ').replace('#',' ').replace('*',' ').replace('\n',' ').replace('·',' ').replace('[',' ').replace(']',' ').split()
            listname.extend(filter_list)
    print(filepath)
    # print(listname)
    return listname

# %%
main_task = list()
make_list('main_task.txt', main_task)
# Out:
# main_task.txt
# ['주요업무',
#  'Docker',
#  '기반',
#  '오피스',
#  '솔루션',
#  '구축',
#  '및',
#  '유지보수',
#  '기업',
#  '요청사항에',
#  '따른',
#  '솔루션',
#  '기능개발',
#  '사용하는',
#  '기술',
#  '및',
#  '환경',
#  'Docker,',
#  'Spring',
#  'Java,',
#  'JPA,',
#  'JavaScript,',
#  'JSP,',
#  'jQuery,',
#  'Ajax,',
#  'HTML5,',
#  'CSS',
#  '주요업무',
#  '번역의',
#  '의뢰부터',
#  '진행/검수/납품/결제까지의',
#  '전',
#  '단계를',
#  '커버하는',
#  '번역',
#  '서비스',
#  '플랫폼을',
#  '만듭니다.',
#  '주요업무',
#  'Unity',
#  '3D',
#  '개발',
#  '디지털',
#  '트윈',
#  '플랫폼',
#  '개발',
#  'Unity',
#  '엔진을',
#  '이용한',
#  '그래픽',
#  '시뮬레이션',
#  '프로그램',
#  '개발',
#  '주요업무',
#  '담당',
#  '업무',
#  'DataSpace',
#  '플랫폼',
#  '설계',
#  '및',
#  '아키텍쳐',
#  '정의',
#  'DataSpace',
#  '플랫폼',
#  '상세',
#  '서비스',
#  '설계',
#  'B2B',
#  '마켓플레이스',
#  '플랫폼',
#  '설계',
#  '검색(SEO),',
#  '추천',
#  '시스템,',
#  '트랜잭션',
#  '설계',
#  '등',
#  '플랫폼',
#  '핵심',
#  '기능',
#  '설계',
#  '데이터',
#  '거래',
#  '중심의',
#  '비즈니스',
#  '프로세스',
#  '최적화서비스',
#  '아키텍처',
#  '설계',
#  '결제',
#  '및',
#  '트랜잭션',
#  '관리',
#  '시스템',
#  '설계',
#  '및',
#  '운영',
#  '데이터',
#  '기반',
#  '고객',
#  '맞춤형',
#  '솔루션',
#  '설계',
#  '디지털',
#  '자산',
#  '거래',
#  '솔루션',
#  '설계',
#  '및',
#  '운영Data',
#  'Space',
#  'R&D',
#  '팀',
#  '리더십',
#  '팀',
#  '빌딩',
#  '및',
#  '조직화',
#  '효율적인',
#  '개발',
#  '환경',
#  '및',
#  '인프라',
#  '구축',
#  '주요업무AI',
#  'Model',
#  'Optimization',
#  '모델',
#  '압축(양자화,',
#  '프루닝',
#  '등),',
#  '연산자',
#  '퓨전,',
#  '메모리',
#  '최적화',
#  '기법을',
#  '활용하여',
#  '모델',
#  '성능',
#  '개선',
#  '및',
#  '모델',
#  '추론',
#  '속도',
#  '향상',
#  'CPU/GPU/NPU등',
#  'HW를',
#  '고려한',
#  'AI모델',
#  '최적화',
#  '기법',
#  '개발',
#  '필요한',
#  'AI',
#  '모듈(예:',
#  '객체',
#  '인식,',
#  '이상',
#  '탐지',
#  '등)을',
#  '최적화하여',
#  '실시간',
#  '실행',
#  '성능',
#  '확보',
#  'AI',
#  '모델',
#  '병렬화',
#  '및',
#  '분산',
#  '실행',
#  '기술',
#  '적용Tool',
#  '체인',
#  '개발',
#  'AI',
#  '모델',
#  '변환',
#  '및',
#  '최적화를',
#  '위한',
#  '툴체인',
#  '설계',
#  '및',
#  '구현신기술',
#  '리서치',
#  '및',
#  '연구',
#  'AI',
#  '및',
#  'Hardware',
#  '가속기',
#  '관련',
#  '최신',
#  '기술',
#  '및',
#  '연구',
#  '동향',
#  '분석',
#  '주요업무',
#  '생성형',
#  'AI',
#  '모델을',
#  '사용하여',
#  '이미지/영상',
#  '합성',
#  '데이터',
#  '생성',
#  '(synthetic',
#  'data',
#  'generation)',
#  '로봇과',
#  '설비의',
#  '물리세계를',
#  '모사하는',
#  '시뮬레이션',
#  '모델',
#  '설계',
#  '(공간관계,',
#  '물리적',
#  '규칙)',
#  '로봇,',
#  '설비가',
#  '물리',
#  '세계를',
#  '인지,',
#  '이해,',
#  '추론하여',
#  '자율적으로',
#  '행동할',
#  '수',
#  '있도록',
#  '가상',
#  '시뮬레이션',
#  '환경에서',
#  '강화',
#  '학습을',
#  '이용하여',
#  '최적의',
#  'action',
#  'policy',
#  '훈련',
#  'Digital',
#  'Twin',
#  '&',
#  'Simulation',
#  '엔지니어,',
#  'Robotics',
#  '엔지니어와',
#  '협업',
#  '주요업무',
#  'Databricks',
#  '환경에서',
#  'Spark',
#  'SQL',
#  '및',
#  'PySpark를',
#  '활용한',
#  '데이터',
#  '파이프라인',
#  '설계',
#  '및',
#  '구현',
#  '서비스',
#  '로그',
#  '및',
#  '유저',
#  '이벤트',
#  '데이터',
#  '수집,',
#  '가공,',
#  '적재',
#  '프로세스',
#  '구축',
#  '전사',
#  '데이터',
#  '마트',
#  '설계',
#  '및',
#  '운영',
#  '데이터',
#  '크롤링',
#  '시스템',
#  '구축',
#  '및',
#  '운영',
#  'ML/AI',
#  '팀과',
#  '협업하여',
#  '모델',
#  '서빙',
#  '파이프라인',
#  '구축',
#  'A/B',
#  '테스트',
#  '등',
#  '실험',
#  '환경',
#  '구축',
#  '및',
#  '운영',
#  '주요업무',
#  '자동차',
#  '전장',
#  '소프트웨어',
#  '개발에',
#  '대한',
#  '검증',
#  '고객',
#  '요구사항',
#  '이해을',
#  '이해하고',
#  'Test',
#  '진행',
#  '성능테스트',
#  '결과',
#  '분석',
#  '및',
#  '레포트',
#  '작성',
#  '개선',
#  '포인트',
#  '도출',
#  '및',
#  '유관부서',
#  '개선',
#  '지원',
#  '주요업무',
#  '고품질',
#  '모바일',
#  '앱',
#  '개발:',
#  'React',
#  'Native로',
#  'iOS/Android에서',
#  '성능과',
#  '안정성이',
#  '높은',
#  '앱',
#  '구현',
#  'UI/UX',
#  '최적화:',
#  '사용자',
#  '중심의',
#  '인터랙티브',
#  'UI와',
#  '부드러운',
#  '애니메이션을',
#  '설계',
#  '상태',
#  '관리:',
#  '데이터',
#  '흐름을',
#  '최적화하여',
#  '성능을',
#  '향상',
#  '반응형',
#  '디자인:',
#  '다양한',
#  '기기에',
#  '최적화된',
#  'UI로',
#  '일관된',
#  '사용자',
#  '경험',
#  '제공',
#  '성능',
#  '모니터링:',
#  '메모리와',
#  '로딩',
#  '속도를',
#  '모니터링하고',
#  '최적화',
#  '코드',
#  '품질',
#  '및',
#  '협업:',
#  '코드',
#  '리뷰,',
#  'Git',
#  '관리,',
#  'CI/CD로',
#  '품질을',
#  '유지하며',
#  '팀과',
#  '협력',
#  '주요업무',
#  'AWS',
#  'Cloud',
#  '인프라',
#  '설계,',
#  '구축,',
#  '운영',
#  'AWS',
#  'EKS',
#  '구축',
#  '관리',
#  'Slack,',
#  'Kubebot,',
#  'Dashboard,',
#  'ArgoCD',
#  'AWS',
#  '비용',
#  '최적화',
#  '관리',
#  '서비스',
#  '장애',
#  '대응,',
#  '분석',
#  '및',
#  '트러블',
#  '슈팅',
#  '및',
#  '주요',
#  '성능지표',
#  '모니터링',
#  'DevOps',
#  ':',
#  'Github',
#  'Action,',
#  'Bitbucket,',
#  'CI/CD,',
#  'Pipeline',
#  '스크립트',
#  '작성',
#  'IDC',
#  ':',
#  'L3',
#  'Switch,',
#  'L2',
#  'Switch,',
#  'L4',
#  'Switch,',
#  '방화벽,',
#  'VPN,',
#  'SSL',
#  'VPN',
#  '주요업무',
#  'UI/UX',
#  '설계',
#  '및',
#  '구현:',
#  '사용자',
#  '친화적이고',
#  '직관적인',
#  '인터페이스를',
#  'React로',
#  '구현하고,',
#  '다양한',
#  '사용자',
#  '흐름을',
#  '최적화하여',
#  '몰입도',
#  '높은',
#  '사용자',
#  '경험',
#  '제공',
#  '컴포넌트',
#  '기반',
#  '시스템',
#  '구축:',
#  '재사용',
#  '가능한',
#  '컴포넌트를',
#  '설계하여',
#  '코드',
#  '일관성과',
#  '효율성을',
#  '높이고,',
#  '디자인',
#  '시스템과',
#  '일치하는',
#  '컴포넌트',
#  '구조',
#  '유지',
#  'API',
#  '연동',
#  '및',
#  '데이터',
#  '관리:',
#  '백엔드',
#  'API와의',
#  '통신을',
#  '통해',
#  '실시간',
#  '데이터를',
#  '반영하고,',
#  '상태',
#  '관리',
#  '라이브러리를',
#  '사용하여',
#  '데이터',
#  '흐름을',
#  '최적화',
#  '반응형',
#  '웹',
#  '및',
#  '크로스',
#  '디바이스',
#  '최적화:',
#  '다양한',
#  '화면',
#  '크기와',
#  '디바이스에서',
#  '일관된',
#  '경험을',
#  '제공할',
#  '수',
#  '있도록',
#  '반응형',
#  '디자인과',
#  '스타일링',
#  '구현',
#  '검색',
#  '및',
#  '필터링',
#  '기능',
#  '강화:',
#  '복잡한',
#  '검색',
#  '필터',
#  '기능',
#  '구현',
#  '및',
#  '최적화를',
#  '통해',
#  '사용자',
#  '편의성',
#  '향상',
#  '성능',
#  '최적화:',
#  '페이지',
#  '로딩',
#  '속도',
#  '개선',
#  '및',
#  '렌더링',
#  '성능',
#  '최적화,',
#  '코드',
#  '스플리팅',
#  '및',
#  'Lazy',
#  'Loading',
#  '적용',
#  '테스트',
#  '및',
#  '디버깅:',
#  '다양한',
#  '브라우저',
#  '및',
#  '기기에서',
#  '일관된',
#  '성능을',
#  '보장하기',
#  '위한',
#  '테스트와',
#  '정기적인',
#  '디버깅',
#  '수행',
#  '코드',
#  '품질',
#  '유지:',
#  '코드',
#  '리뷰,',
#  'Git,',
#  'CI/CD',
#  '파이프라인',
#  '활용을',
#  '통해',
#  '코드',
#  '품질',
#  '및',
#  '일관성',
#  '유지',
#  '주요업무',
#  '자사',
#  '서비스의',
#  '전반적인',
#  'QA',
#  '활동',
#  '요구사항에',
#  '대한',
#  '분석',
#  '및',
#  '결함,',
#  '개선안',
#  '도출',
#  '리스크',
#  '분석',
#  '및',
#  '목표',
#  '품질',
#  '커버리지',
#  '설정',
#  '테스트',
#  '계획',
#  '및',
#  '설계,',
#  '실행',
#  '지속적인',
#  '이슈',
#  '트래킹',
#  '및',
#  '프로파일링',
#  '주도적인',
#  '품질',
#  '향상',
#  '활동을',
#  '통한',
#  '품질',
#  '보증',
#  '주요업무',
#  '홈페이지',
#  '개편:',
#  '디자인과',
#  '기능을',
#  '최신화하여',
#  '사용자',
#  '친화적인',
#  '웹사이트',
#  '개편',
#  '작업',
#  '수행',
#  'React',
#  '환경에서',
#  '퍼블리싱:',
#  'React를',
#  '활용해',
#  '웹',
#  '페이지를',
#  '구현하고',
#  '최적화',
#  '팀원과의',
#  '협력',
#  '및',
#  '의견',
#  '제시:',
#  '디자인,',
#  '개발',
#  '팀원들과',
#  '협력하며',
#  '서비스',
#  '이해를',
#  '바탕으로',
#  '개선',
#  '의견',
#  '제안',
#  '크로스',
#  '브라우저',
#  '호환성',
#  '테스트:',
#  '다양한',
#  '브라우저와',
#  '기기에서',
#  '일관된',
#  '사용자',
#  '경험',
#  '보장',
#  '팁스',
#  '프로그램',
#  '연구개발',
#  '참여:',
#  '팁스',
#  '프로그램',
#  '관련',
#  '연구개발',
#  '프로젝트에',
#  '기여',
#  '주요업무아워플레이스의',
#  '백엔드',
#  '개발자는',
#  '플랫폼의',
#  '핵심',
#  '시스템을',
#  '설계,',
#  '구축,',
#  '유지',
#  '관리하는',
#  '중요한',
#  '역할을',
#  '담당합니다.',
#  '안정적이고',
#  '확장',
#  '가능한',
#  '인프라를',
#  '제공하며,',
#  '데이터',
#  '흐름을',
#  '최적화하고',
#  '사용자',
#  '경험을',
#  '뒷받침하는',
#  'API를',
#  '개발합니다.',
#  '특히',
#  '사용자',
#  '맞춤형',
#  '경험을',
#  '제공하기',
#  '위해',
#  '노출',
#  '알고리즘',
#  '개발',
#  '및',
#  '최적화에',
#  '기여합니다.주요',
#  '업무',
#  '시스템',
#  '설계',
#  '및',
#  '개발',
#  '안정적이고',
#  '확장',
#  '가능한',
#  '서버',
#  '아키텍처',
#  '설계',
#  '대규모',
#  '트래픽을',
#  '처리할',
#  '수',
#  '있는',
#  '데이터베이스',
#  '설계',
#  '및',
#  '최적화',
#  '노출',
#  '알고리즘',
#  '설계',
#  '및',
#  '최적화',
#  '사용자',
#  '맞춤형',
#  '추천',
#  '시스템',
#  '개발',
#  '및',
#  '유지',
#  '검색',
#  '결과',
#  '및',
#  '콘텐츠',
#  '노출',
#  '알고리즘',
#  '설계',
#  'AI를',
#  '활용한',
#  '추천',
#  '모델',
#  '연구',
#  '및',
#  '적용',
#  '실시간',
#  '데이터',
#  '처리',
#  '및',
#  '개인화',
#  '전략',
#  '구현',
#  '플랫폼',
#  '유지',
#  '및',
#  '개선',
#  '서비스',
#  '성능',
#  '모니터링',
#  '및',
#  '문제',
#  '해결',
#  '데이터',
#  '보안',
#  '정책',
#  '수립',
#  '및',
#  '구현',
#  '코드',
#  '품질',
#  '및',
#  '테스트',
#  '프로세스',
#  '개선',
#  '협업',
#  '및',
#  '지원',
#  '프론트엔드,',
#  '디자인,',
#  'CX',
#  '팀과',
#  '협력하여',
#  '사용자',
#  '중심',
#  '기능',
#  '구현',
#  '제품',
#  '로드맵에',
#  '따른',
#  '개발',
#  '일정',
#  '관리',
#  '기술',
#  '문서',
#  '작성',
#  '및',
#  '팀',
#  '내',
#  '지식',
#  '공유',
#  '주요업무',
#  '어떤',
#  '일을',
#  '담당하나요?',
#  '스토어링크',
#  '백엔드',
#  '서비스',
#  '개발',
#  '및',
#  '운영',
#  '퍼그샵',
#  '백엔드',
#  '서비스',
#  '개발',
#  '및',
#  '운영',
#  '신규',
#  '서비스의',
#  'DB',
#  '모델링,',
#  '도메인',
#  '분석,',
#  '설계,',
#  '개발',
#  '및',
#  '운영',
#  '주요업무본',
#  '포지션은',
#  'EQST(화이트해커',
#  '그룹)',
#  'Lab에서',
#  '근무합니다.',
#  'V8',
#  '신규',
#  '보안',
#  '취약점',
#  '분석',
#  '및',
#  '연구',
#  '주요업무본',
#  '포지션은',
#  'EQST(화이트해커',
#  '그룹)',
#  'Lab에서',
#  '근무합니다.',
#  '랜섬웨어',
#  '샘플',
#  '분석',
#  '및',
#  '공격자',
#  '그룹',
#  '프로파일링',
#  '랜섬웨어',
#  '최신',
#  '동향',
#  '분석',
#  '및',
#  '보고서',
#  '작성',
#  '주요업무본',
#  '포지션은',
#  'EQST(화이트해커',
#  '그룹)',
#  'Lab에서',
#  '근무합니다.',
#  'AI',
#  'LLM',
#  '취약점',
#  '분석',
#  '및',
#  '대응',
#  '방안',
#  '연구',
#  'AI',
#  'LLM',
#  '기반',
#  '서비스',
#  '보안',
#  '평가',
#  '기준',
#  '수립',
#  'AI',
#  'LLM',
#  '서비스',
#  '보안성',
#  '진단',
#  '및',
#  '취약점',
#  '점검',
#  '주요업무',
#  '고객',
#  '시스템에서',
#  '발생하는',
#  '장애나',
#  '성능',
#  '이슈를',
#  '더',
#  '쉽고',
#  '빠르게',
#  '해결하는데',
#  '도움을',
#  '주는',
#  '서비스를',
#  '개발합니다.',
#  '모니터링',
#  '데이터',
#  '중',
#  'Time',
#  'Series',
#  '데이터에',
#  '대한',
#  '이상탐지(Anomaly',
#  'Detection)',
#  '방법을',
#  '연구하여',
#  '적용합니다.',
#  '모니터링',
#  '데이터를',
#  '기반으로',
#  '머신',
#  '러닝(ML)',
#  '활용',
#  '방안',
#  '연구하여',
#  '적용',
#  '합니다.',
#  '모니터링',
#  '플렛폼에서',
#  'Generative',
#  'AI',
#  '활용방안을',
#  '연구하여',
#  '적용합니다.',
#  '주요업무데이오프의',
#  'FE개발자는',
#  '데이오프',
#  '서비스',
#  '프로그램의',
#  'FE',
#  '파트에',
#  '대한',
#  '개발',
#  '및',
#  '운영을',
#  '담당합니다.',
#  '기술',
#  '스택',
#  'React,',
#  'Next.js',
#  '(v.13',
#  'App',
#  'routing),',
#  'Typescript',
#  'HTML5,',
#  'CSS,',
#  'TailwindCSS',
#  'Recoil,',
#  'Tanstack',
#  'Query,',
#  'React',
#  'Hook',
#  'Form',
#  'Android',
#  'Flutter',
#  '&',
#  'Native',
#  'IOS',
#  '앱내',
#  '웹뷰',
#  'Github,',
#  'Jira,',
#  'Notion,',
#  'Slack',
#  'REST',
#  'API',
#  'AWS',
#  'Admin',
#  'React,',
#  'Next.js',
#  '(version',
#  '14,',
#  'app',
#  'routing),',
#  'TypeScript',
#  'TailwindCSS,',
#  'Shadcn,',
#  'Headless',
#  'UI',
#  'Tanstack',
#  'Query,',
#  'React',
#  'Hook',
#  ...]

# %%
print(main_task)
# Out:
# ['주요업무', 'Docker', '기반', '오피스', '솔루션', '구축', '및', '유지보수', '기업', '요청사항에', '따른', '솔루션', '기능개발', '사용하는', '기술', '및', '환경', 'Docker,', 'Spring', 'Java,', 'JPA,', 'JavaScript,', 'JSP,', 'jQuery,', 'Ajax,', 'HTML5,', 'CSS', '주요업무', '번역의', '의뢰부터', '진행/검수/납품/결제까지의', '전', '단계를', '커버하는', '번역', '서비스', '플랫폼을', '만듭니다.', '주요업무', 'Unity', '3D', '개발', '디지털', '트윈', '플랫폼', '개발', 'Unity', '엔진을', '이용한', '그래픽', '시뮬레이션', '프로그램', '개발', '주요업무', '담당', '업무', 'DataSpace', '플랫폼', '설계', '및', '아키텍쳐', '정의', 'DataSpace', '플랫폼', '상세', '서비스', '설계', 'B2B', '마켓플레이스', '플랫폼', '설계', '검색(SEO),', '추천', '시스템,', '트랜잭션', '설계', '등', '플랫폼', '핵심', '기능', '설계', '데이터', '거래', '중심의', '비즈니스', '프로세스', '최적화서비스', '아키텍처', '설계', '결제', '및', '트랜잭션', '관리', '시스템', '설계', '및', '운영', '데이터', '기반', '고객', '맞춤형', '솔루션', '설계', '디지털', '자산', '거래', '솔루션', '설계', '및', '운영Data', 'Space', 'R&D', '팀', '리더십', '팀', '빌딩', '및', '조직화', '효율적인', '개발', '환경', '및', '인프라', '구축', '주요업무AI', 'Model', 'Optimization', '모델', '압축(양자화,', '프루닝', '등),', '연산자', '퓨전,', '메모리', '최적화', '기법을', '활용하여', '모델', '성능', '개선', '및', '모델', '추론', '속도', '향상', 'CPU/GPU/NPU등', 'HW를', '고려한', 'AI모델', '최적화', '기법', '개발', '필요한', 'AI', '모듈(예:', '객체', '인식,', '이상', '탐지', '등)을', '최적화하여', '실시간', '실행', '성능', '확보', 'AI', '모델', '병렬화', '및', '분산', '실행', '기술', '적용Tool', '체인', '개발', 'AI', '모델', '변환', '및', '최적화를', '위한', '툴체인', '설계', '및', '구현신기술', '리서치', '및', '연구', 'AI', '및', 'Hardware', '가속기', '관련', '최신', '기술', '및', '연구', '동향', '분석', '주요업무', '생성형', 'AI', '모델을', '사용하여', '이미지/영상', '합성', '데이터', '생성', '(synthetic', 'data', 'generation)', '로봇과', '설비의', '물리세계를', '모사하는', '시뮬레이션', '모델', '설계', '(공간관계,', '물리적', '규칙)', '로봇,', '설비가', '물리', '세계를', '인지,', '이해,', '추론하여', '자율적으로', '행동할', '수', '있도록', '가상', '시뮬레이션', '환경에서', '강화', '학습을', '이용하여', '최적의', 'action', 'policy', '훈련', 'Digital', 'Twin', '&', 'Simulation', '엔지니어,', 'Robotics', '엔지니어와', '협업', '주요업무', 'Databricks', '환경에서', 'Spark', 'SQL', '및', 'PySpark를', '활용한', '데이터', '파이프라인', '설계', '및', '구현', '서비스', '로그', '및', '유저', '이벤트', '데이터', '수집,', '가공,', '적재', '프로세스', '구축', '전사', '데이터', '마트', '설계', '및', '운영', '데이터', '크롤링', '시스템', '구축', '및', '운영', 'ML/AI', '팀과', '협업하여', '모델', '서빙', '파이프라인', '구축', 'A/B', '테스트', '등', '실험', '환경', '구축', '및', '운영', '주요업무', '자동차', '전장', '소프트웨어', '개발에', '대한', '검증', '고객', '요구사항', '이해을', '이해하고', 'Test', '진행', '성능테스트', '결과', '분석', '및', '레포트', '작성', '개선', '포인트', '도출', '및', '유관부서', '개선', '지원', '주요업무', '고품질', '모바일', '앱', '개발:', 'React', 'Native로', 'iOS/Android에서', '성능과', '안정성이', '높은', '앱', '구현', 'UI/UX', '최적화:', '사용자', '중심의', '인터랙티브', 'UI와', '부드러운', '애니메이션을', '설계', '상태', '관리:', '데이터', '흐름을', '최적화하여', '성능을', '향상', '반응형', '디자인:', '다양한', '기기에', '최적화된', 'UI로', '일관된', '사용자', '경험', '제공', '성능', '모니터링:', '메모리와', '로딩', '속도를', '모니터링하고', '최적화', '코드', '품질', '및', '협업:', '코드', '리뷰,', 'Git', '관리,', 'CI/CD로', '품질을', '유지하며', '팀과', '협력', '주요업무', 'AWS', 'Cloud', '인프라', '설계,', '구축,', '운영', 'AWS', 'EKS', '구축', '관리', 'Slack,', 'Kubebot,', 'Dashboard,', 'ArgoCD', 'AWS', '비용', '최적화', '관리', '서비스', '장애', '대응,', '분석', '및', '트러블', '슈팅', '및', '주요', '성능지표', '모니터링', 'DevOps', ':', 'Github', 'Action,', 'Bitbucket,', 'CI/CD,', 'Pipeline', '스크립트', '작성', 'IDC', ':', 'L3', 'Switch,', 'L2', 'Switch,', 'L4', 'Switch,', '방화벽,', 'VPN,', 'SSL', 'VPN', '주요업무', 'UI/UX', '설계', '및', '구현:', '사용자', '친화적이고', '직관적인', '인터페이스를', 'React로', '구현하고,', '다양한', '사용자', '흐름을', '최적화하여', '몰입도', '높은', '사용자', '경험', '제공', '컴포넌트', '기반', '시스템', '구축:', '재사용', '가능한', '컴포넌트를', '설계하여', '코드', '일관성과', '효율성을', '높이고,', '디자인', '시스템과', '일치하는', '컴포넌트', '구조', '유지', 'API', '연동', '및', '데이터', '관리:', '백엔드', 'API와의', '통신을', '통해', '실시간', '데이터를', '반영하고,', '상태', '관리', '라이브러리를', '사용하여', '데이터', '흐름을', '최적화', '반응형', '웹', '및', '크로스', '디바이스', '최적화:', '다양한', '화면', '크기와', '디바이스에서', '일관된', '경험을', '제공할', '수', '있도록', '반응형', '디자인과', '스타일링', '구현', '검색', '및', '필터링', '기능', '강화:', '복잡한', '검색', '필터', '기능', '구현', '및', '최적화를', '통해', '사용자', '편의성', '향상', '성능', '최적화:', '페이지', '로딩', '속도', '개선', '및', '렌더링', '성능', '최적화,', '코드', '스플리팅', '및', 'Lazy', 'Loading', '적용', '테스트', '및', '디버깅:', '다양한', '브라우저', '및', '기기에서', '일관된', '성 ...

# %%
prefered = list()
make_list('prefered.txt', prefered)
# Out:
# prefered.txt
# ['우대사항',
#  'Linux',
#  '서버',
#  '운영',
#  '경험자',
#  'Docker',
#  '환경에서',
#  '서비스',
#  '유경험자',
#  '서버',
#  '이중화',
#  '유경험자',
#  '서버',
#  '기반의',
#  '제품',
#  '서비스',
#  '유경험자',
#  '고객',
#  '요구사항',
#  '관련',
#  '미팅',
#  '및',
#  '유지보수/구축업무를',
#  '위한',
#  '외근',
#  '및',
#  '출장',
#  '가능한',
#  '분',
#  '제출자료',
#  '이력서(자기소개서와',
#  '기본',
#  '인적사항',
#  '기재해주세요.)',
#  '경력기술서',
#  '포트폴리오',
#  '(선택사항)',
#  '우대사항',
#  'Microservice',
#  'Architecture에',
#  '익숙하신',
#  '분',
#  'Domain',
#  'driven',
#  'Development에',
#  '관심이',
#  '있거나',
#  '조예가',
#  '깊으신',
#  '분',
#  '대용량',
#  'Transaction',
#  '처리',
#  '경험이',
#  '있으신',
#  '분',
#  'Concurrent',
#  'Programming에',
#  '경험이',
#  '있으신',
#  '분',
#  'Socket',
#  'programming',
#  '경험이',
#  '있으신',
#  '분',
#  'DevOps',
#  '경험이',
#  '있으신',
#  '분',
#  '우대사항컴퓨터공학,',
#  '기계공학',
#  '전공하신',
#  '분',
#  '컴퓨터',
#  '그래픽스에',
#  '대한',
#  '이해도를',
#  '보유하신',
#  '분',
#  '디지털',
#  '트윈',
#  '개념과',
#  '응용',
#  '사례',
#  '경험이',
#  '있으신',
#  '분',
#  '클라이언트',
#  '서버',
#  '구조의',
#  '네트워크',
#  '(TCP,UDP)',
#  '연동',
#  '경험이',
#  '있으신',
#  '분',
#  '개발',
#  '설계',
#  '문서',
#  '작성이',
#  '가능하신',
#  '분',
#  '작업',
#  '내용',
#  '및',
#  '가이드',
#  '문서화',
#  '할',
#  '수',
#  '있는',
#  '능력을',
#  '보유하신',
#  '분',
#  '자발적이고',
#  '능동적인',
#  '제안과',
#  '개발',
#  '진행이',
#  '가능하신',
#  '분',
#  '우대사항',
#  '우대사항',
#  '글로벌',
#  'B2B',
#  '플랫폼',
#  '설계',
#  '경험R&D',
#  '조직',
#  '관리',
#  '및',
#  '팀',
#  '빌딩',
#  '경험제조',
#  'AI,',
#  '데이터',
#  '거래',
#  '플랫폼',
#  '설계',
#  '경험',
#  '우대사항',
#  '하드웨어',
#  '가속기(e.g.,',
#  'FPGA)에서',
#  '머신러닝',
#  '및',
#  '딥러닝',
#  '모델',
#  '최적화',
#  '경험이',
#  '있으신',
#  '분',
#  '클라우드',
#  '기반',
#  'AI',
#  '솔루션',
#  '및',
#  '엣지',
#  '컴퓨팅',
#  '시스템과의',
#  '통합',
#  '(integration)',
#  '경험이',
#  '있으신',
#  '분',
#  'NPU',
#  'SW',
#  'Toolkit',
#  '(Compiler,',
#  'Quantizer,',
#  'Runtime',
#  '등)',
#  '개발',
#  '경험이',
#  '있으신',
#  '분',
#  '팀',
#  '환경',
#  '내에서',
#  '개별적으로',
#  '또는',
#  '협력적으로',
#  '일할',
#  '수',
#  '있는',
#  '능력이',
#  '있으신',
#  '분',
#  '우대사항',
#  '강화학습/시뮬레이션',
#  '전공',
#  '박사',
#  '학위를',
#  '보유하신',
#  '분',
#  '로봇,',
#  '설비',
#  '자율운전을',
#  '위한',
#  '강화학습/시뮬레이션',
#  '경험이',
#  '있으신',
#  '분',
#  'AI,',
#  'Robotics',
#  '관련',
#  'Top',
#  'SCI급',
#  '저널',
#  '기고,',
#  '특허',
#  '보유하신',
#  '분',
#  '우대사항Databricks',
#  '환경에서의',
#  '개발',
#  '경험',
#  'Flink',
#  '등',
#  '실시간',
#  '처리',
#  '시스템',
#  '활용',
#  '경험',
#  'AWS',
#  '등',
#  '클라우드',
#  '환경에서의',
#  '개발',
#  '경험',
#  '백엔드',
#  '개발',
#  '경험',
#  'A/B',
#  '테스트',
#  '플랫폼',
#  '구축',
#  '경험',
#  'ML/AI',
#  '모델',
#  '서빙',
#  '경험',
#  '우대사항',
#  '차량용',
#  'SW',
#  '개발/검증',
#  '경험',
#  'C,',
#  'C++,',
#  'JAVA',
#  '프로그래밍',
#  '경력',
#  'Android',
#  'Platform에',
#  '대한',
#  '품질보증',
#  '경험이',
#  '있으신',
#  '분',
#  '관련',
#  '부서와',
#  '커뮤니케이션을',
#  '하고',
#  '주도적으로',
#  '업무',
#  '추진이',
#  '가능한',
#  '분',
#  '우대사항',
#  'TypeScript',
#  '사용',
#  '경험',
#  'SEO',
#  '및',
#  '웹',
#  '접근성에',
#  '대한',
#  '이해',
#  'CI/CD',
#  '파이프라인',
#  '구축',
#  '및',
#  '운영',
#  '경험',
#  '우대사항',
#  '전공',
#  '혹은',
#  '경험을',
#  '보유한',
#  '분',
#  '인프라',
#  '운영',
#  '유지',
#  '보수에',
#  '대한',
#  '경험이',
#  '있는',
#  '분',
#  'Docker',
#  '경험이',
#  '있으신',
#  '분',
#  'IDC',
#  '인프라',
#  '설계',
#  '경험이',
#  '있으신',
#  '분',
#  '우대사항',
#  '대규모',
#  '웹',
#  '애플리케이션이나',
#  '플랫폼',
#  '개발',
#  '경험',
#  'SEO',
#  '최적화',
#  '및',
#  '웹',
#  '접근성에',
#  '대한',
#  '지식',
#  'TypeScript',
#  '사용',
#  '경험',
#  'CI/CD',
#  '파이프라인',
#  '구축',
#  '및',
#  '활용',
#  '경험',
#  '문제',
#  '해결을',
#  '위한',
#  '창의적이고',
#  '논리적인',
#  '사고',
#  '능력',
#  '우대사항',
#  'QA',
#  '활동을',
#  '운영하고',
#  '리드한',
#  '경험이',
#  '있으신',
#  '분',
#  '다양한',
#  '테스트',
#  '방법론',
#  '적용',
#  '경험이',
#  '있으신',
#  '분',
#  '앱/웹/서버',
#  '등',
#  '플랫폼별',
#  '특성을',
#  '이해하고',
#  '계신',
#  '분',
#  '프로세스',
#  '개선',
#  '및',
#  '테스트',
#  '환경',
#  '구축',
#  '경험이',
#  '있으신',
#  '분',
#  '우대사항',
#  '크로스',
#  '플랫폼',
#  '디자인',
#  '시스템',
#  '구축',
#  '경험:',
#  '여러',
#  '플랫폼에서',
#  '일관된',
#  '디자인',
#  '시스템을',
#  '구축한',
#  '경험이',
#  '있는',
#  '분',
#  '코드',
#  '퀄리티',
#  '향상',
#  '의지:',
#  '코드의',
#  '품질을',
#  '지속적으로',
#  '개선하고',
#  '유지하려는',
#  '자세를',
#  '갖춘',
#  '분',
#  '플랫폼',
#  '구축',
#  '경험:',
#  '플랫폼',
#  '구축',
#  '경험이',
#  '있으신',
#  '분',
#  '고난도',
#  '성능',
#  '문제',
#  '해결',
#  '경험:',
#  '고난도',
#  '성능',
#  '문제를',
#  '진단하고',
#  '해결한',
#  '경험이',
#  '있는',
#  '분',
#  '데이터',
#  '수집',
#  '및',
#  '분석',
#  '툴',
#  '경험:',
#  '데이터',
#  '수집과',
#  '분석',
#  '툴에',
#  '대한',
#  '경험과',
#  '관심이',
#  '많은',
#  '분',
#  '우대사항',
#  '마켓플레이스',
#  '플랫폼',
#  '또는',
#  '대규모',
#  '웹',
#  '서비스',
#  '구축',
#  '경험',
#  '추천',
#  '시스템,',
#  '검색',
#  '엔진,',
#  '또는',
#  '머신러닝',
#  '모델',
#  '개발',
#  '경험',
#  '데이터',
#  '보안',
#  '및',
#  '개인정보',
#  '보호',
#  '관련',
#  '경험',
#  '스타트업',
#  '환경에서의',
#  '개발',
#  '경험',
#  '우대사항',
#  '이런',
#  '점이',
#  '있으면',
#  '더욱',
#  '좋아요!',
#  'Spring',
#  'Webflux',
#  '사용',
#  '경험이',
#  '있으신',
#  '분',
#  '운영',
#  '도중',
#  '발생한',
#  '장애를',
#  '겪고',
#  '스스로',
#  '고민해',
#  '해결해보신',
#  '분',
#  '객체지향',
#  '프로그래밍',
#  '원리와',
#  'SOLID',
#  '원칙을',
#  '깊이',
#  '이해하고',
#  '적용할',
#  '수',
#  '있는',
#  '분',
#  '테스트',
#  '코드',
#  '작성과',
#  '코드',
#  '리뷰',
#  '및',
#  '피드백을',
#  '긍정적으로',
#  '받아들일',
#  '수',
#  '있는',
#  '자세를',
#  '가진',
#  '분',
#  '지속적인',
#  '학습과',
#  '성장을',
#  '추구하는',
#  '자기주도적인',
#  '열정을',
#  '가진',
#  '분',
#  '우대사항',
#  '브라우저',
#  '버그바운티',
#  '및',
#  'CVE',
#  '등록',
#  '경험자',
#  'CTF',
#  '수상',
#  '또는',
#  '본선',
#  '진출자',
#  '관련',
#  '학과',
#  '연구실/동아리',
#  '등',
#  '활동',
#  '경험자',
#  '원활한',
#  '커뮤니케이션',
#  '역량',
#  '보유자',
#  '영어',
#  '커뮤니케이션',
#  '가능자',
#  '우대사항',
#  '악성코드',
#  '분석',
#  '업무',
#  '경력자',
#  '다양한',
#  '파일',
#  '포맷의',
#  '악성코드',
#  '분석',
#  '경험자',
#  'CTI',
#  '시스템',
#  '구축/활용',
#  '및',
#  '분석',
#  '경험자',
#  'TTPs,',
#  'MITRE',
#  'ATT&CK',
#  '이해',
#  '보유자',
#  '원활한',
#  '커뮤니케이션',
#  '역량',
#  '보유자',
#  '우대사항',
#  'LLM',
#  '기반',
#  '서비스',
#  '개발',
#  '경험자',
#  '보안',
#  '가이드라인',
#  '수립',
#  '경험자',
#  'AI',
#  '보안',
#  '프로세스',
#  '및',
#  '정책',
#  '설계/개발',
#  '경험자',
#  '원활한',
#  '커뮤니케이션',
#  '역량',
#  '보유자',
#  '우대사항',
#  '책임감을',
#  '바탕으로',
#  '능동적이고',
#  '자율적으로',
#  '동료와',
#  '소통하며',
#  '업무를',
#  '수행하는',
#  '분',
#  '본인의',
#  '생각을',
#  '논리적으로',
#  '설명할',
#  '수',
#  '있는',
#  '분',
#  '개인의',
#  '역량을',
#  '성장',
#  '시키고자',
#  '하는',
#  '의지가',
#  '강하신',
#  '분',
#  '라이브러리',
#  '제작',
#  '또는',
#  '오픈소스에',
#  '기여하신',
#  '경험이',
#  '있으신',
#  '분',
#  '모니터링',
#  '서비스',
#  '사용',
#  '경험이',
#  '있으신',
#  '분',
#  'Application,',
#  'Server,',
#  'DB,',
#  'kubernetes',
#  '등',
#  '모니터링',
#  '데이터에',
#  '대한',
#  '이해가',
#  '있으신',
#  '분',
#  '우대사항',
#  '실제',
#  '엔드유저',
#  '대상',
#  '서비스',
#  '개발',
#  '및',
#  '운영',
#  '경험이',
#  '있으신',
#  '분',
#  '웹뷰',
#  '서비스',
#  '개발',
#  '및',
#  '운영',
#  '경험',
#  'AWS',
#  '인프라',
#  '구축',
#  '경험',
#  '더',
#  '좋은',
#  '사용성',
#  '개선안,',
#  '개발',
#  '문화',
#  '발전에',
#  '대한',
#  '다양한',
#  '아이디어가',
#  '있으신',
#  '분',
#  '새로운',
#  '배움을',
#  '통해',
#  '끊임없이',
#  '성장하는',
#  '것을',
#  '즐기는',
#  '분',
#  '논리적이고',
#  '체계적인',
#  '문제해결',
#  '능력이',
#  '있으신',
#  '분',
#  '우대사항',
#  '영상',
#  '데이터나',
#  'GIS',
#  '데이터를',
#  '활용한',
#  '개발',
#  '경험',
#  'AWS',
#  '및',
#  '클라우드',
#  '개발',
#  '및',
#  '운영',
#  '경험',
#  '지도',
#  '관련',
#  '라이브러리(leaflet,',
#  'openlayers,',
#  '네이버',
#  '지도,',
#  '카카오',
#  '지도',
#  '등)',
#  '활용',
#  '경험이',
#  '있으신',
#  '분',
#  'React,',
#  'TypeScript를',
#  '이용한',
#  '개발',
#  '및',
#  '운영',
#  '경험이',
#  '있으신',
#  '분',
#  'Golang',
#  '실무',
#  '개발',
#  '경험',
#  'gRPC',
#  '실무',
#  '개발',
#  '경험',
#  '우대사항',
#  '임베디드',
#  'Linux',
#  '기본지식',
#  '보유',
#  '디바이스',
#  '드라이버,',
#  '커널',
#  '프로그래밍,',
#  'DTS',
#  '관련',
#  '개발',
#  '경험',
#  '보유',
#  'MCU',
#  '및',
#  '주변',
#  '기기',
#  '관련',
#  '개발',
#  '경험',
#  '우대사항',
#  '알고리즘',
#  '문제',
#  '풀이에',
#  '몰입한',
#  '경험이',
#  '있으신',
#  '분',
#  '개발에',
#  'ChatGPT,',
#  'Claude,',
#  'Cursor,',
#  'Windsurf',
#  '등을',
#  '적극적으로',
#  '활용하시는',
#  '분',
#  '원활한',
#  '협업',
#  '커뮤니케이션',
#  '역량을',
#  '보유하신',
#  '분',
#  '우대사항',
#  'E',
#  'commerce',
#  'Service',
#  '개발/운영',
#  '경험',
#  'HTML5',
#  'Video',
#  'Tag',
#  '기반',
#  'Video',
#  '처리',
#  '경험',
#  'Web',
#  '기반',
#  'CMS',
#  '개발/운영',
#  '경험',
#  '우대사항',
#  '머신비전',
#  '개발',
#  '경험',
#  '(OpenCV,',
#  'Halcon,',
#  '비전카메라',
#  '등)',
#  '클라우드,',
#  '온프로미스',
#  '기반',
#  'ML',
#  '파이프라인',
#  '구축',
#  '경험',
#  '(MLflow,',
#  'Kubeflow',
#  '등)',
#  '임베디드/에지',
#  '디바이스',
#  'ML',
#  '모델',
#  '개발',
#  '경험',
#  'Data',
#  'structure,',
#  'Algorithm,',
#  'OS',
#  '등',
#  'CS',
#  '지식',
#  'Docker',
#  '컨테이너',
#  '기반',
#  'CI/CD',
#  '경험',
#  '우대사항',
#  '실시간',
#  '챗/메시지',
#  '시스템',
#  '개발',
#  '및',
#  '운영',
#  '경험',
#  '높은',
#  '동시',
#  '접속',
#  '및',
#  '대용량',
#  '트래픽',
#  '처리',
#  '경험',
#  'Unix/Linux',
#  '시스템',
#  '운영',
#  '경험',
#  'Event',
#  'driven',
#  'framework에',
#  '대한',
#  '이해',
#  'TCP/IP',
#  '및',
#  '네트워크',
#  '프로그래밍',
#  '이해',
#  'RDBMS,',
#  'NoSQL',
#  '및',
#  '분산',
#  '데이터베이스',
#  '이해',
#  '및',
#  '경험',
#  '서버',
#  '가상화,',
#  '글로벌',
#  '인프라,',
#  '부하',
#  '분산',
#  '및',
#  '대량',
#  '데이터',
#  '트래픽',
#  '처리에',
#  '대한',
#  '이해',
#  '및',
#  '경험',
#  '프로젝트',
#  '단위',
#  '개발',
#  '조직',
#  '리딩',
#  '경험',
#  '우대사항',
#  '딥러닝',
#  '기반',
#  '알고리즘',
#  '개발',
#  '경력자',
#  '석/박사',
#  '학위자',
#  '우대',
#  '우대사항',
#  'ChatGPT',
#  '등',
#  'AI',
#  '산업에',
#  '관심',
#  '있으신',
#  '분',
#  '블록체인',
#  '개발',
#  '경험이',
#  '있으신',
#  '분',
#  '대용량',
#  '데이터',
#  '및',
#  '트래픽을',
#  '고려한',
#  '개발',
#  '경험이',
#  '있으신',
#  '분',
#  'CI/CD에',
#  '대한',
#  '이해도와',
#  '경험을',
#  '보유하신',
#  '분',
#  '퍼포먼스',
#  '분석',
#  '및',
#  '최적화',
#  '경험이',
#  '있으신',
#  '분',
#  '테스트',
#  '중요성에',
#  '대한',
#  '이해도와',
#  '테스트',
#  '자동화',
#  '경험이',
#  '있으신',
#  '분',
#  '트러블',
#  '슈팅',
#  '및',
#  '문제',
#  '해결',
#  '경험이',
#  '있으신',
#  '분',
#  'Git',
#  '및',
#  '협업툴(Slack,',
#  'Google',
#  'Workspace',
#  '등)을',
#  '통한',
#  '업무',
#  '및',
#  '커뮤니케이션',
#  '경험이',
#  '있으신',
#  '분',
#  '우대사항',
#  'Kubernetes',
#  '관련',
#  '인증(CKA,',
#  'CKAD',
#  '등)',
#  '보유자',
#  '고가용성',
#  '및',
#  '분산',
#  '시스템',
#  '설계',
#  '경험',
#  '로컬',
#  '및',
#  '클라우드',
#  '하이브리드',
#  '환경',
#  '운영',
#  '경험',
#  '소프트웨어',
#  '개발',
#  '및',
#  '테스트',
#  '환경에',
#  '대한',
#  '이해',
#  '우대사항',
#  'MSA',
#  'Architect',
#  '경험',
#  'S/W',
#  '개발',
#  '경험(예:',
#  'Java,',
#  'Python,',
#  'C/C++)',
#  'Golang,',
#  'Python',
#  ...]

# %%
required = list()
make_list('required.txt', required)
# Out:
# required.txt
# ['자격요건',
#  '자격요건',
#  '신입',
#  '~',
#  '경력',
#  '6년',
#  '이하',
#  'Spring',
#  '기반',
#  'Java',
#  'API',
#  '구현',
#  '및',
#  '내부',
#  '서비스',
#  '구현',
#  'HTML5,',
#  'CSS3',
#  '웹',
#  '표준에',
#  '대한',
#  '이해',
#  'JS(ES6)/HTML/CSS를',
#  '이용해',
#  '웹',
#  '페이지',
#  '개발',
#  '가능하신',
#  '분',
#  'RDBMS(MariaDB)',
#  '사용',
#  '경험이',
#  '있으신',
#  '분',
#  '고객사와',
#  '원활하게',
#  '소통이',
#  '가능하며',
#  '외근',
#  '및',
#  '출장',
#  '업무에',
#  '거부감이',
#  '없으신',
#  '분',
#  '필요지식',
#  '및',
#  '기술',
#  'Spring',
#  '기반',
#  'Java',
#  'API',
#  '구현',
#  '및',
#  '내부',
#  '서비스',
#  '구현',
#  'HTML5,',
#  'CSS3',
#  '웹',
#  '표준에',
#  '대한',
#  '이해',
#  'JavaScript에',
#  '대한',
#  '이해',
#  '및',
#  '활용',
#  'shell',
#  'script에',
#  '대한',
#  '이해',
#  '이런',
#  '분을',
#  '선호해요!',
#  '새로운',
#  'AI',
#  '기술과',
#  '트렌드에',
#  '대한',
#  '열린',
#  '자세로',
#  '끊임없이',
#  '학습',
#  '적용하며,',
#  '변화에',
#  '유연하게',
#  '대응하는',
#  '태도가',
#  '좋은',
#  '분',
#  '협업',
#  '동료와의',
#  '원활한',
#  '커뮤니케이션을',
#  '바탕으로',
#  '협업을',
#  '이끌어내고,',
#  '요구사항을',
#  '정확히',
#  '파악하여',
#  '반영하는',
#  '태도가',
#  '좋은',
#  '분',
#  '사용자',
#  '중심의',
#  '관점과',
#  '논리적',
#  '사고를',
#  '통해',
#  '문제를',
#  '파악하고',
#  '해결책을',
#  '제시할',
#  '수',
#  '있는',
#  '태도가',
#  '좋은',
#  '분',
#  '자격요건',
#  '매너있지만',
#  '확실하게',
#  '자기',
#  '주장하시는분',
#  'Rust',
#  '혹은',
#  '프로그래밍에',
#  '대한',
#  '깊은',
#  '이해가',
#  '있으신',
#  '분',
#  'CI/CD',
#  '프로세스에',
#  '대한',
#  '조예가',
#  '있으신',
#  '분',
#  'System',
#  'design의',
#  'Trade',
#  'off에',
#  '대한',
#  '논의를',
#  '좋아하시는',
#  '분',
#  'Execution이',
#  '빠르신',
#  '분',
#  '자격요건',
#  '유관',
#  '경력',
#  '5년',
#  '이상의',
#  'C',
#  '개발',
#  '경험',
#  '또는',
#  '이에',
#  '준하는',
#  '역량과',
#  '이해도를',
#  '보유하신',
#  '분',
#  'C',
#  ',',
#  '알고리즘',
#  '이해,',
#  '네트워크',
#  '프로그래밍',
#  '경험이',
#  '있으신',
#  '분',
#  '자료구조,',
#  '알고리즘',
#  '및',
#  '객체지향',
#  '개발에',
#  '대한',
#  '지식과',
#  '경험이',
#  '있으신',
#  '분',
#  'Unity',
#  '엔진을',
#  '이용한',
#  '디지털',
#  '트윈',
#  '구현',
#  '경험이',
#  '있으신',
#  '분',
#  'TCP,',
#  'UDP',
#  '를',
#  '이용한',
#  '클라이언트',
#  '서버',
#  '구조의',
#  '패킷',
#  '통신에',
#  '대한',
#  '이해도를',
#  '보유하신',
#  '분',
#  '6개월',
#  '이상의',
#  '장기',
#  '프로젝트',
#  '경험과',
#  '협업에',
#  '대한',
#  '이해가',
#  '있으신',
#  '분',
#  '자격요건',
#  '필수',
#  '경험과',
#  '역량',
#  '10년',
#  '이상',
#  '대규모',
#  '전자상거래',
#  '플랫폼',
#  '아키텍트',
#  '경력검색/추천',
#  '시스템',
#  '또는',
#  '트랜잭션',
#  '설계',
#  '경험DevOps',
#  '인프라',
#  '구축',
#  '및',
#  '개발',
#  '경험',
#  '자격요건',
#  '컴퓨터',
#  '공학,',
#  'AI',
#  '또는',
#  '관련',
#  '분야',
#  '석사',
#  '학위를',
#  '소지하신',
#  '분',
#  'PyTorch,',
#  'ONNX,',
#  'TensorFlow',
#  'Lite',
#  '와',
#  '같은',
#  '딥러닝',
#  '프레임워크',
#  '및',
#  '모델',
#  '변환',
#  '도구',
#  '사용',
#  '경험이',
#  '있으신',
#  '분',
#  '양자화,',
#  '프루닝,',
#  '지연',
#  '평가(Lazy',
#  'Evaluation)와',
#  '같은',
#  '모델',
#  '압축',
#  '및',
#  '최적화',
#  '기술에',
#  '대한',
#  '이해도가',
#  '높으신',
#  '분',
#  'CPU,',
#  'GPU,',
#  'NPU을',
#  '활용한',
#  'AI',
#  '최적화',
#  '경험이',
#  '있으신',
#  '분',
#  '프로그래밍',
#  '언어',
#  'Python',
#  '및',
#  'C++',
#  '활용',
#  '능력이',
#  '높으신',
#  '분',
#  '자격요건',
#  '강화학습',
#  '이론에',
#  '대한',
#  '깊은',
#  '이해와',
#  '강화학습',
#  'Framework',
#  '경험이',
#  '있으신',
#  '분',
#  '(예:',
#  'Stable',
#  'Baselines3,',
#  'RLlib,',
#  'Acme',
#  '등)',
#  '생성형',
#  'AI',
#  '모델',
#  '(VAE,',
#  'Diffusion',
#  'models,',
#  'NVIDIA',
#  'Cosmos)',
#  '개발',
#  '경험이',
#  '있으신',
#  '분',
#  'Computer',
#  'Vision:',
#  'CNNs,',
#  'Vision',
#  'Transformers(ViTs),',
#  'image',
#  'tokenizer',
#  '경험이',
#  '있으신',
#  '분',
#  '시뮬레이션',
#  '환경(NVIDIA',
#  'Omniverse,',
#  'Isaac',
#  'Sim,',
#  'Unity)',
#  '개발',
#  '경험이',
#  '있으신',
#  '분',
#  'Python,',
#  'PyTorch',
#  '경험이',
#  '있으신',
#  '분',
#  '자격요건',
#  '3년',
#  '이상의',
#  '데이터',
#  '엔지니어링',
#  '경험을',
#  '보유하신',
#  '분',
#  'Spark',
#  '기반',
#  '데이터',
#  '처리',
#  '및',
#  '분석',
#  '경험이',
#  '있으신',
#  '분',
#  '(SQL,',
#  'PySpark)',
#  '다음',
#  '중',
#  '하나',
#  '이상의',
#  '데이터베이스',
#  '실무',
#  '경험이',
#  '있으신',
#  '분:',
#  'Elasticsearch,',
#  'MongoDB,',
#  'MySQL',
#  '데이터',
#  '파이프라인',
#  '설계',
#  '및',
#  '운영',
#  '경험을',
#  '보유하신',
#  '분',
#  '자격요건',
#  'QA',
#  '경력',
#  '3년이상',
#  '차량',
#  '임베디드',
#  '시스템에',
#  '대한',
#  '이해',
#  'QA',
#  '엔지니어/테스트',
#  '엔지니어',
#  '역할에',
#  '대한',
#  '이해도',
#  '일정',
#  '협의,',
#  'QA',
#  '계획',
#  '수립,',
#  'TC작성,',
#  '테스트',
#  '수행,',
#  '버그',
#  '리포팅,',
#  '테스트',
#  '결과',
#  '공유',
#  '등',
#  '해외',
#  '출장',
#  '및',
#  '근무에',
#  '결격',
#  '사유',
#  '없으신',
#  '분',
#  '자격요건',
#  '개발',
#  '경력:',
#  'Objective',
#  'C,',
#  'Java,',
#  'React',
#  'Native를',
#  '활용한',
#  '3년',
#  '이상의',
#  '개발',
#  '경험',
#  '또는',
#  '이에',
#  '준하는',
#  '능력',
#  '서비스',
#  '개발',
#  '및',
#  '배포',
#  '경험:',
#  'Objective',
#  'C,',
#  'Java,',
#  'React',
#  'Native로',
#  '실제',
#  '서비스',
#  '개발',
#  '및',
#  '배포',
#  '경험',
#  '보유',
#  'React',
#  'Native',
#  '및',
#  'JavaScript',
#  '숙련도:',
#  'React',
#  'Native를',
#  '포함한',
#  'JavaScript에',
#  '대한',
#  '깊은',
#  '이해와',
#  '실무',
#  '경험',
#  '모바일',
#  '애플리케이션',
#  '개발',
#  '경험:',
#  'iOS/Android',
#  '플랫폼에서의',
#  '앱',
#  '개발',
#  '및',
#  '배포',
#  '경험',
#  'UI/UX',
#  '이해도:',
#  '사용자',
#  '경험을',
#  '고려한',
#  '인터랙티브',
#  'UI',
#  '및',
#  '반응형',
#  '디자인',
#  '구현',
#  '능력',
#  '상태',
#  '관리',
#  '라이브러리',
#  '경험:',
#  '복잡한',
#  '데이터',
#  '흐름',
#  '관리',
#  '경험',
#  '성능',
#  '최적화',
#  '경험:',
#  '코드',
#  '스플리팅,',
#  'Lazy',
#  'Loading,',
#  '메모리',
#  '최적화',
#  '등',
#  '성능',
#  '향상',
#  '기법',
#  '적용',
#  '경험',
#  '테스트',
#  '작성',
#  '및',
#  '디버깅',
#  '능력:',
#  'Jest,',
#  'Detox',
#  '등',
#  '테스트',
#  '프레임워크',
#  '활용',
#  '경험',
#  '협업',
#  '및',
#  '커뮤니케이션',
#  '능력:',
#  'Git,',
#  '코드',
#  '리뷰',
#  '경험과',
#  '다양한',
#  '팀원과의',
#  '원활한',
#  '협업',
#  '능력',
#  '자격요건',
#  '경력',
#  ':',
#  '3년~6년',
#  '자격요건',
#  'React',
#  '및',
#  'JavaScript에',
#  '대한',
#  '깊은',
#  '이해:',
#  '최신',
#  'React',
#  '기능과',
#  'JavaScript에',
#  '대한',
#  '숙련도',
#  'HTML/CSS와',
#  '프론트엔드',
#  '기본',
#  '지식:',
#  '웹',
#  '표준을',
#  '준수한',
#  '마크업과',
#  '스타일링',
#  '경험',
#  '상태',
#  '관리',
#  '라이브러리',
#  '경험:',
#  '상태',
#  '관리',
#  '라이브러리',
#  '사용',
#  '경험',
#  '및',
#  '효율적인',
#  '데이터',
#  '흐름',
#  '구축',
#  '능력',
#  '비동기',
#  '프로그래밍',
#  '및',
#  'API',
#  '연동',
#  '경험:',
#  'API와의',
#  '통신을',
#  '통해',
#  '데이터',
#  '연동을',
#  '처리하고',
#  '비동기',
#  '요청을',
#  '관리할',
#  '수',
#  '있는',
#  '능력',
#  '반응형',
#  '웹',
#  '디자인',
#  '구현',
#  '능력:',
#  '다양한',
#  '디바이스',
#  '환경에',
#  '맞춰',
#  '반응형',
#  'UI를',
#  '개발한',
#  '경험',
#  '성능',
#  '최적화',
#  '경험:',
#  'Lazy',
#  'Loading,',
#  '코드',
#  '스플리팅,',
#  '캐싱',
#  '등',
#  '성능',
#  '향상',
#  '기법',
#  '적용',
#  '경험',
#  '협업',
#  '도구',
#  '활용',
#  '능력:',
#  'Git,',
#  'Jira,',
#  'Slack',
#  '등',
#  '협업',
#  '도구를',
#  '활용하여',
#  '효율적인',
#  '팀워크를',
#  '경험한',
#  '이력',
#  '3년',
#  '이상',
#  '프론트엔드',
#  '개발',
#  '경력:',
#  '최소',
#  '3년',
#  '이상의',
#  '프론트엔드',
#  '개발',
#  '경력,',
#  '특히',
#  'React',
#  '기반',
#  '프로젝트',
#  '경험',
#  '자격요건',
#  '자사',
#  '플랫폼',
#  'QA',
#  '경력',
#  '3년',
#  '이상',
#  '또는',
#  '이에',
#  '준하는',
#  '실무',
#  '경험',
#  '프로젝트',
#  '기획',
#  '단계부터',
#  '릴리즈까지',
#  '전체',
#  '사이클',
#  '경험이',
#  '있으신',
#  '분',
#  '신속한',
#  '대처',
#  '능력과',
#  '책임감을',
#  '가지신',
#  '분',
#  'DevOps,',
#  'SDLC에',
#  '대한',
#  '이해가',
#  '높으신',
#  '분',
#  '자격요건',
#  'HTML,',
#  'CSS,',
#  'React',
#  '이해도:',
#  'HTML,',
#  'CSS,',
#  'React에',
#  '대한',
#  '깊은',
#  '이해와',
#  '실무',
#  '경험',
#  '반응형',
#  '웹',
#  '퍼블리싱',
#  '경험:',
#  '반응형',
#  '웹',
#  '퍼블리싱',
#  '4년',
#  '이상',
#  '경력',
#  '또는',
#  '이에',
#  '준하는',
#  '개발',
#  '능력',
#  '동적',
#  '인터랙티브',
#  '구현:',
#  '다양한',
#  '동적',
#  '인터랙티브',
#  '효과를',
#  '구현할',
#  '수',
#  '있는',
#  '능력',
#  '데이터',
#  '바인딩',
#  '고려한',
#  '컴포넌트',
#  '작업:',
#  '데이터',
#  '바인딩을',
#  '고려하여',
#  'React',
#  '컴포넌트를',
#  '설계하고',
#  '구현하는',
#  '능력',
#  '문제',
#  '해결',
#  '능력:',
#  '다양한',
#  '문제에',
#  '대해',
#  '체계적인',
#  '원인',
#  '분석',
#  '및',
#  '해결',
#  '능력',
#  '보유',
#  '협업',
#  '및',
#  '커뮤니케이션',
#  '스킬:',
#  '팀원들과',
#  '원활하게',
#  '소통하고',
#  '협력할',
#  '수',
#  '있는',
#  '능력',
#  '자격요건',
#  '5년',
#  '이상의',
#  '백엔드',
#  '개발',
#  '경험',
#  '데이터베이스',
#  '설계',
#  '및',
#  '최적화',
#  '경험',
#  '클라우드',
#  '환경(AWS,',
#  'GCP,',
#  'Azure',
#  '등)에서의',
#  '서비스',
#  '운영',
#  '경험',
#  'API',
#  '설계',
#  '및',
#  '개발',
#  '경험',
#  'CI/CD',
#  '및',
#  '테스트',
#  '자동화에',
#  '대한',
#  '이해',
#  '데이터',
#  '기반',
#  '의사결정',
#  '및',
#  '알고리즘',
#  '개발',
#  '경험',
#  '자격요건',
#  '어떤',
#  '조건이',
#  '필요한가요?',
#  '웹',
#  '어플리케이션',
#  '백엔드',
#  '개발',
#  '4년',
#  '이상',
#  '경력이',
#  '있는',
#  '분',
#  '(필수)',
#  'Java/Kotiln',
#  '중에서',
#  '하나',
#  '이상의',
#  '프로그래밍',
#  '언어에',
#  '능숙하신',
#  '분',
#  'Spring',
#  'Framework(Spring',
#  'Boot)',
#  '를',
#  '이용한',
#  '웹',
#  '애플리케이션',
#  '개발',
#  '경험과',
#  '문제해결',
#  '능력이',
#  '있으신',
#  '분',
#  'REST',
#  'API',
#  '설계',
#  '및',
#  '개발',
#  '경험이',
#  '있으신',
#  '분',
#  'ORM',
#  '기술에',
#  '거부감이',
#  '없고',
#  '능숙하게',
#  '다룰',
#  '수',
#  '있는',
#  '분',
#  'RDBMS',
#  '기반의',
#  '웹어플리케이션',
#  '모델링/개발',
#  '능력이',
#  '있으신',
#  '분',
#  '주요',
#  '기술',
#  '스택',
#  'Spring',
#  'Boot,',
#  'Webflux/MVC,',
#  'Kotlin/Java,',
#  'JPA,',
#  'MySQL,',
#  'JDBC/R2DBC,',
#  'Redis,',
#  'Gradle',
#  '환경',
#  ':',
#  'AWS,',
#  'Elastic',
#  'Beanstalk,',
#  'Aurora',
#  'Serverless,',
#  'Elastic',
#  'Cache,',
#  'Jenkins,',
#  'Github',
#  'Actions',
#  '협업',
#  '도구:',
#  'Github,',
#  'Notion,',
#  'JIRA,',
#  'Swagger,',
#  'Figma,',
#  'Discord',
#  '개발',
#  '도구',
#  ':',
#  'IntelliJ',
#  '자격요건',
#  '유관',
#  '경력',
#  '3년',
#  '이상',
#  '브라우저',
#  '취약점',
#  '분석',
#  '경험자',
#  '시스템해킹(Pwnable)',
#  '기술',
#  '역량',
#  '보유자',
#  '자격요건',
#  '유관',
#  '경력',
#  '3년',
#  '이상',
#  '악성코드',
#  '및',
#  'CTI',
#  '등',
#  '관련',
#  '기술',
#  '이해자',
#  '코드',
#  '분석',
#  '및',
#  '개발',
#  '역량',
#  '보유자',
#  '자격요건',
#  '유관',
#  '경력',
#  '3년',
#  '이상',
#  '웹/모바일',
#  '앱/API/AI',
#  '기반',
#  '서비스',
#  '보안성',
#  '점검',
#  '및',
#  '취약점',
#  '분석',
#  '경험자',
#  'AI',
#  '보안',
#  '관련',
#  '연구',
#  '또는',
#  '프로젝트',
#  '경험자',
#  '자격요건',
#  'LangChain,',
#  'LlamaIndex,',
#  'AutoGen과',
#  '같은',
#  '프레임워크',
#  '개발',
#  '경험',
#  'Python,',
#  'Java',
#  '등',
#  '1개',
#  '이상의',
#  'Applicaion',
#  '개발',
#  '경험을',
#  '보유하신',
#  '분',
#  '최신',
#  '딥러닝',
#  '동향에',
#  '대한',
#  '이해가',
#  '있으신',
#  '분',
#  '자격요건',
#  'React,',
#  'Next.js',
#  '및',
#  'TypeScript를',
#  '이용해',
#  '서비스',
#  '개발',
#  '및',
#  '운영이',
#  '가능한',
#  '분',
#  'SSR',
#  '및',
#  'CSR에',
#  '대한',
#  ...]

# %%
benefit = list()
make_list('benefit.txt', benefit)
# Out:
# benefit.txt
# ['혜택',
#  '및',
#  '복지',
#  'Polaris',
#  'Office',
#  'Culture',
#  '■',
#  '성장의',
#  '에너지를',
#  '경험해요!',
#  '폴라리스오피스는',
#  '가파르게',
#  '성장하며',
#  '지금은',
#  '5개',
#  '상장사로',
#  '구성된',
#  '폴라리스오피스그룹의',
#  '모회사가',
#  '되었어요.',
#  '구성원으로',
#  '합류한다면',
#  '성장의',
#  '에너지와',
#  '문화를',
#  '경험할',
#  '수',
#  '있어요!',
#  '국내',
#  '최초',
#  '온디바이스',
#  'AI',
#  '오피스',
#  '솔루션으로',
#  '글로벌',
#  '1억',
#  '3천만명',
#  '이상의',
#  '가입자를',
#  '보유하고',
#  '있어요!',
#  '높은',
#  '트래픽을',
#  '지닌',
#  '서비스를',
#  '경험하며',
#  '성장하고',
#  '커리어도',
#  'Level',
#  'Up!',
#  '할',
#  '수',
#  '있어요.',
#  '개발자가',
#  '성장할',
#  '수',
#  '있는',
#  '문화를',
#  '지향해요.',
#  'Devday,',
#  '개인',
#  '연구시간',
#  '부여,',
#  '직무',
#  '관련',
#  '도서/교육비를',
#  '폭넓게',
#  '지원하며',
#  '새로운',
#  '기술을',
#  '경험하고',
#  '성장할',
#  '수',
#  '있는',
#  '환경을',
#  '만들어가고',
#  '있어요.',
#  '■',
#  '커뮤니케이션은',
#  '수평적으로,',
#  '업무는',
#  '체계적으로',
#  '해요!',
#  '영어',
#  '호칭을',
#  '사용한',
#  '지',
#  '무려',
#  '10년차!',
#  '유연한',
#  '커뮤니케이션을',
#  '위해',
#  '직급을',
#  '사용하지',
#  '않고',
#  '누구나',
#  '적극적으로',
#  '의견을',
#  '낼',
#  '수',
#  '있는',
#  '환경을',
#  '만들었어요.',
#  '“Meet',
#  'up',
#  'with',
#  'Project”',
#  '행사를',
#  '통해',
#  '프로젝트별',
#  '목표와',
#  '성과를',
#  '전사에',
#  '공유하고',
#  '회고하는',
#  '시간을',
#  '가져요.',
#  '프로젝트',
#  '구성원',
#  '모두가',
#  '목표를',
#  '생각하고',
#  '동기부여될',
#  '수',
#  '있는',
#  '‘등대’와도',
#  '같은',
#  '행사에요.',
#  'Teams,',
#  'Confluence',
#  '와',
#  '같은',
#  '협업툴을',
#  '적극',
#  '활용하여',
#  '산출물은',
#  '투명하게',
#  '관리하고',
#  '불필요한',
#  '보고체계는',
#  '최소화하여',
#  '보다',
#  '집중해서',
#  '업무에',
#  '몰두할',
#  '수',
#  '있어요.■',
#  '자율과',
#  '책임의',
#  '조직문화를',
#  '기반으로',
#  '혁신적인',
#  '근무제도를',
#  '시행하고있어요.',
#  '원격지에',
#  '거주하는',
#  '개발인재는',
#  '100%',
#  '재택근무를',
#  '지원해요.',
#  '연고지에서',
#  '이전',
#  '불필요!',
#  '출퇴근',
#  '비용과',
#  '시간',
#  '절감까지',
#  '하고',
#  '업무효율도',
#  '높일',
#  '수',
#  '있어요.',
#  '퇴근',
#  '후',
#  '저녁이',
#  '있는',
#  '삶을',
#  '존중해요.',
#  '하이브리드',
#  '근무제를',
#  '운영해서',
#  '주2회',
#  '재택근무와',
#  '자율출퇴근제를',
#  '사용해요.',
#  '8시~10시',
#  '30분',
#  '까지',
#  '자유롭게',
#  '출근하고',
#  '야근하는',
#  '날이',
#  '있으면',
#  '다른',
#  '날',
#  '일찍',
#  '퇴근할',
#  '수',
#  '있어요.',
#  '■',
#  'Work',
#  '&',
#  'Life',
#  'Synergy',
#  '!',
#  '휴식이',
#  '있어야',
#  '즐겁게',
#  '일할',
#  '수',
#  '있고',
#  '생산성과',
#  '만족도도',
#  '높아져요!',
#  '일하는',
#  '시간보다는',
#  '성과와',
#  '도전에',
#  '더',
#  '집중해요.',
#  '불필요한',
#  '야근을',
#  '줄이고',
#  '업무효율성을',
#  '높이는',
#  '근무환경을',
#  '만들어가고',
#  '있어요.',
#  '당일',
#  '연차사용도',
#  'OK!',
#  '매년',
#  '전직원이',
#  '99%',
#  '이상',
#  '연차를',
#  '사용하고',
#  '있어요.',
#  '가족과',
#  '함께',
#  '소중한',
#  '날을',
#  '보낼',
#  '수',
#  '있도록',
#  '연2회',
#  '패밀리데이(유급휴가)도',
#  '지원해요.',
#  'Benefits',
#  '든든한',
#  '점심식사',
#  '1만원',
#  '지원!',
#  '급한',
#  '용무',
#  '볼',
#  '수',
#  '있는',
#  '반반차(외출)',
#  '휴가제도',
#  '운영',
#  '더',
#  '행복한',
#  '생일을',
#  '위한',
#  '20만원',
#  '상당의',
#  '백화점',
#  '상품권',
#  '지원',
#  '동반가족',
#  '1인',
#  '포함',
#  '종합건강검진',
#  '지원',
#  '자녀',
#  '초등학교',
#  '입학선물',
#  '지원',
#  '신규입사',
#  'Welcome',
#  'Kit,',
#  '임신직원',
#  'Maternity',
#  'Kit',
#  '지원',
#  '1년에',
#  '2번,',
#  '가족과',
#  '오붓한',
#  '시간을',
#  '보낼',
#  '수',
#  '있는',
#  'Family',
#  'Day',
#  '질병,',
#  '부상',
#  '관련',
#  '본인',
#  '의료비',
#  '지원',
#  '자기개발',
#  '및',
#  '어학능력',
#  '향상을',
#  '위한',
#  '외국어',
#  '교육비',
#  '지원',
#  '직무',
#  '관련',
#  '도서구입비',
#  '지원',
#  '임직원',
#  '생활안정자금',
#  '대출제도',
#  '운영',
#  '결혼축하금',
#  '100만원',
#  '및',
#  '7일',
#  '휴가지원,',
#  '본인/배우자',
#  '출산선물',
#  '지원',
#  '중소기업',
#  '청년',
#  '소득세',
#  '감면제도',
#  '운영',
#  '휴게실,',
#  '안마의자,',
#  '커피머신,',
#  '음료',
#  '등',
#  '입사하면',
#  '더',
#  '많은',
#  '혜택이!',
#  '혜택',
#  '및',
#  '복지',
#  '최신형',
#  '노트북',
#  '제공',
#  '(맥북/기타)',
#  '주',
#  '1회',
#  '재택근무',
#  '(선택',
#  '가능)',
#  '점심시간',
#  '제외',
#  '7시간',
#  '근무',
#  '유연근무제',
#  '운영',
#  '(8시부터',
#  '11시까지',
#  '자유롭게',
#  '출근하세요!)',
#  '도서구입비/교육비',
#  '무제한',
#  '지원',
#  '과자,',
#  '음료,',
#  '주류(?!)',
#  '등',
#  '간식',
#  '무제한',
#  '제공',
#  '혜택',
#  '및',
#  '복지',
#  '복지',
#  '패키지',
#  '인터엑스에만',
#  '있는',
#  '지원',
#  '직무역량',
#  '및',
#  '자기계발',
#  '교육과정',
#  'IX',
#  'Academy',
#  '직무별',
#  '커리어',
#  '성장',
#  '지원',
#  '역량',
#  '진단',
#  '제도',
#  '‘IX',
#  'Expert',
#  '성과별',
#  '보상',
#  'Compensation',
#  'Package',
#  '3년',
#  '근속',
#  '시,',
#  '5일',
#  '휴가',
#  'or',
#  '100만원',
#  '보너스',
#  '중소기업',
#  '청년',
#  '소득세',
#  '감면',
#  '지원',
#  'Work',
#  'Environment',
#  '업무',
#  '관련',
#  '도서',
#  '구입',
#  '무한지원',
#  '사내',
#  '스터디',
#  '지원',
#  '(시험',
#  '합격',
#  '시,',
#  '응시비용',
#  '전액',
#  '지원)',
#  '최신식',
#  'IT',
#  '장비',
#  '지원',
#  '자율',
#  '복장과',
#  '수평적인',
#  '조직문화',
#  '자유로운',
#  '연차',
#  '&',
#  '1시간단위',
#  '시간차',
#  '사용',
#  'Refresh',
#  '효율적인',
#  '협업을',
#  '위해',
#  '팀간',
#  '협업',
#  '지원비',
#  '사내동호회',
#  '운영',
#  '비용',
#  '지원',
#  '생일',
#  '유급',
#  '반차',
#  '경조',
#  '휴가/경조금',
#  '지원',
#  '(회사의',
#  '복지제도는',
#  '상황에',
#  '따라',
#  '유연하게',
#  '변경될',
#  '수',
#  '있습니다.)',
#  '혜택',
#  '및',
#  '복지',
#  '복지',
#  '패키지',
#  '인터엑스에만',
#  '있는',
#  '지원',
#  '직무역량',
#  '및',
#  '자기계발',
#  '교육과정',
#  'IX',
#  'Academy',
#  '직무별',
#  '커리어',
#  '성장',
#  '지원',
#  '역량',
#  '진단',
#  '제도',
#  '‘IX',
#  'Expert',
#  '성과별',
#  '보상',
#  'Compensation',
#  'Package',
#  '3년',
#  '근속',
#  '시,',
#  '5일',
#  '휴가',
#  'or',
#  '100만원',
#  '보너스',
#  '중소기업',
#  '청년',
#  '소득세',
#  '감면',
#  '지원',
#  'Work',
#  'Environment',
#  '업무',
#  '관련',
#  '도서',
#  '구입',
#  '무한지원',
#  '사내',
#  '스터디',
#  '지원',
#  '(시험',
#  '합격',
#  '시,',
#  '응시비용',
#  '전액',
#  '지원)',
#  '최신식',
#  'IT',
#  '장비',
#  '지원',
#  '자율',
#  '복장과',
#  '수평적인',
#  '조직문화',
#  '자유로운',
#  '연차',
#  '&',
#  '1시간단위',
#  '시간차',
#  '사용',
#  'Refresh',
#  '효율적인',
#  '협업을',
#  '위해',
#  '팀간',
#  '협업',
#  '지원비',
#  '사내동호회',
#  '운영',
#  '비용',
#  '지원',
#  '생일',
#  '유급',
#  '반차',
#  '경조',
#  '휴가/경조금',
#  '지원',
#  '(회사의',
#  '복지제도는',
#  '상황에',
#  '따라',
#  '유연하게',
#  '변경될',
#  '수',
#  '있습니다.)',
#  '혜택',
#  '및',
#  '복지',
#  '복지',
#  '패키지',
#  '인터엑스에만',
#  '있는',
#  '지원',
#  '직무역량',
#  '및',
#  '자기계발',
#  '교육과정',
#  'IX',
#  'Academy',
#  '직무별',
#  '커리어',
#  '성장',
#  '지원',
#  '역량',
#  '진단',
#  '제도',
#  '‘IX',
#  'Expert',
#  '성과별',
#  '보상',
#  'Compensation',
#  'Package',
#  '3년',
#  '근속',
#  '시,',
#  '5일',
#  '휴가',
#  'or',
#  '100만원',
#  '보너스',
#  '중소기업',
#  '청년',
#  '소득세',
#  '감면',
#  '지원',
#  'Work',
#  'Environment',
#  '업무',
#  '관련',
#  '도서',
#  '구입',
#  '무한지원',
#  '사내',
#  '스터디',
#  '지원',
#  '(시험',
#  '합격',
#  '시,',
#  '응시비용',
#  '전액',
#  '지원)',
#  '최신식',
#  'IT',
#  '장비',
#  '지원',
#  '자율',
#  '복장과',
#  '수평적인',
#  '조직문화',
#  '자유로운',
#  '연차',
#  '&',
#  '1시간단위',
#  '시간차',
#  '사용',
#  'Refresh',
#  '효율적인',
#  '협업을',
#  '위해',
#  '팀간',
#  '협업',
#  '지원비',
#  '사내동호회',
#  '운영',
#  '비용',
#  '지원',
#  '생일',
#  '유급',
#  '반차',
#  '경조',
#  '휴가/경조금',
#  '지원',
#  '(회사의',
#  '복지제도는',
#  '상황에',
#  '따라',
#  '유연하게',
#  '변경될',
#  '수',
#  '있습니다.)',
#  '혜택',
#  '및',
#  '복지',
#  '복지',
#  '패키지',
#  '인터엑스에만',
#  '있는',
#  '지원',
#  '직무역량',
#  '및',
#  '자기계발',
#  '교육과정',
#  'IX',
#  'Academy',
#  '직무별',
#  '커리어',
#  '성장',
#  '지원',
#  '역량',
#  '진단',
#  '제도',
#  '‘IX',
#  'Expert',
#  '성과별',
#  '보상',
#  'Compensation',
#  'Package',
#  '3년',
#  '근속',
#  '시,',
#  '5일',
#  '휴가',
#  'or',
#  '100만원',
#  '보너스',
#  '중소기업',
#  '청년',
#  '소득세',
#  '감면',
#  '지원',
#  'Work',
#  'Environment',
#  '업무',
#  '관련',
#  '도서',
#  '구입',
#  '무한지원',
#  '사내',
#  '스터디',
#  '지원',
#  '(시험',
#  '합격',
#  '시,',
#  '응시비용',
#  '전액',
#  '지원)',
#  '최신식',
#  'IT',
#  '장비',
#  '지원',
#  '자율',
#  '복장과',
#  '수평적인',
#  '조직문화',
#  '자유로운',
#  '연차',
#  '&',
#  '1시간단위',
#  '시간차',
#  '사용',
#  'Refresh',
#  '효율적인',
#  '협업을',
#  '위해',
#  '팀간',
#  '협업',
#  '지원비',
#  '사내동호회',
#  '운영',
#  '비용',
#  '지원',
#  '생일',
#  '유급',
#  '반차',
#  '경조',
#  '휴가/경조금',
#  '지원',
#  '(회사의',
#  '복지제도는',
#  '상황에',
#  '따라',
#  '유연하게',
#  '변경될',
#  '수',
#  '있습니다.)',
#  '혜택',
#  '및',
#  '복지',
#  '최고의',
#  '업무',
#  '환경',
#  '전좌석',
#  '모션데스크',
#  '및',
#  '프리미엄',
#  '체어(스틸케이스)',
#  '최신형',
#  '업무',
#  '장비와',
#  '추가',
#  '물품',
#  '필요시',
#  '구매',
#  '지원',
#  '유연한',
#  '출퇴근',
#  '시간과',
#  '승인없는',
#  '휴가',
#  '사용',
#  '오피스로',
#  '찾아오는',
#  '점심',
#  '케이터링과',
#  '무제한',
#  '간식',
#  '부득이한',
#  '야근시',
#  '저녁식사와',
#  '택시비',
#  '지원',
#  '성장과',
#  '자기계발',
#  '지원',
#  '업무',
#  '관련',
#  '도서',
#  '무제한',
#  '지원',
#  '및',
#  '사내',
#  '북클럽',
#  '운영',
#  '직무',
#  '역량',
#  '향상을',
#  '위한',
#  '강의',
#  '무제한',
#  '지원',
#  '컨퍼런스',
#  '참여',
#  '지원',
#  '스포츠,',
#  '교육',
#  '등',
#  '취미',
#  '계발비',
#  '지원',
#  '업무와',
#  '생활의',
#  '균형잡힌',
#  '행복',
#  '종합',
#  '건강검진',
#  '및',
#  '건강검진',
#  '휴가',
#  '지원',
#  '구성원과',
#  '가족의',
#  '생일,',
#  '결혼기념일',
#  '반반차',
#  '휴가',
#  '지원',
#  '생일날',
#  '생일',
#  '선물,',
#  '명절마다',
#  '상품권',
#  '지급',
#  '장기근속시',
#  '휴가비와',
#  '리프레시',
#  '휴가',
#  '3주',
#  '지원',
#  '경조사',
#  '지원(휴가와',
#  '경조금)',
#  '및',
#  '모성보호',
#  '제도',
#  '운영',
#  '신규',
#  '입사시',
#  'L',
#  'lunch',
#  '지원',
#  '혜택',
#  '및',
#  '복지',
#  '기본에',
#  '충실!:',
#  '4대',
#  '보험,',
#  '연차',
#  '및',
#  '여름휴가,',
#  '육아휴직,',
#  '인정휴가,',
#  '직급별',
#  '건강검진',
#  '차등',
#  '지원',
#  '개인능력',
#  '향상을',
#  '위해!:',
#  '외국어',
#  '그룹',
#  '과외,',
#  '업무',
#  '관련',
#  '교육',
#  '및',
#  '도서',
#  '지원',
#  '편안한',
#  '근무를',
#  '위해!:',
#  '시간차근무제,',
#  '자유복장,',
#  '휴게실,',
#  '야근',
#  '시',
#  '택시비',
#  '지원',
#  '쾌적한',
#  '근무를',
#  '위해!',
#  ':공기청정기',
#  '지급,',
#  '고사양',
#  '디바이스,',
#  '사무용품',
#  '세팅',
#  '개인의',
#  '행복을',
#  '위해!:',
#  '자유로운',
#  '연차/반차,',
#  '경조사비,',
#  '명절',
#  '귀향비',
#  '입의',
#  '즐거움을',
#  '위해!:',
#  '커피',
#  '및',
#  '간식',
#  '무제한',
#  '제공',
#  '혜택',
#  '및',
#  '복지',
#  '최신,',
#  '최고',
#  '사양의',
#  '장비',
#  '지원',
#  '창의적',
#  '작업',
#  '환경에서',
#  '성장할',
#  '기회',
#  '제공',
#  '사내외',
#  '교육,',
#  '세미나',
#  '비용',
#  '전액',
#  '지원',
#  '업무',
#  '관련',
#  '도서',
#  '구입비',
#  '지원',
#  '점심',
#  '식사',
#  '제공',
#  '혜택',
#  '및',
#  '복지',
#  '중식제공',
#  '월',
#  '1회',
#  '카머스데이',
#  '휴무',
#  '체력단련비',
#  '제공',
#  '혜택',
#  '및',
#  '복지',
#  '최신,',
#  '최고',
#  '사양의',
#  '장비',
#  '지원',
#  '창의적',
#  '작업',
#  '환경에서',
#  '성장할',
#  '기회',
#  '제공',
#  '사내외',
#  '교육,',
#  '세미나',
#  '비용',
#  '전액',
#  '지원',
#  '업무',
#  '관련',
#  '도서',
#  '구입비',
#  '지원',
#  '점심',
#  '식사',
#  '제공',
#  '혜택',
#  '및',
#  '복지',
#  '최신,',
#  '최고',
#  '사양의',
#  '장비',
#  '지원',
#  '창의적',
#  '작업',
#  '환경에서',
#  '성장할',
#  '기회',
#  '제공',
#  ...]

# %%
text = """나랏말이 중국과 달라 한자와 서로 통하지 아니하므로,
우매한 백성들이 말하고 싶은 것이 있어도 마침내 제 뜻을 잘 표현하지 못하는 사람이 많다.
내 이를 딱하게 여기어 새로 스물여덟 자를 만들었으니,
사람들로 하여금 쉬 익히어 날마다 쓰는 데 편하게 할 뿐이다."""
okt = Okt()
# morphs(text): 텍스트를 형태소 단위로 나눔
okt_morphs = okt.morphs(text)
print('morphs():\n', okt_morphs)
# 명사만 추출
okt_nouns = okt.nouns(text)
print('nouns():\n', okt_nouns)
# phrases(text): 어절 추출
okt_phrases = okt.phrases(text)
print('phrases():\n', okt_phrases)
# pos(text): 품사를 태깅
okt_pos = okt.pos(text)
print('pos():\n', okt_pos)
# Out:
# morphs():
#  ['나랏말', '이', '중국', '과', '달라', '한자', '와', '서로', '통', '하지', '아니하므로', ',', '\n', '우매', '한', '백성', '들', '이', '말', '하고', '싶은', '것', '이', '있어도', '마침내', '제', '뜻', '을', '잘', '표현', '하지', '못', '하는', '사람', '이', '많다', '.', '\n', '내', '이를', '딱하게', '여기어', '새로', '스물', '여덟', '자를', '만들었으니', ',', '\n', '사람', '들', '로', '하여금', '쉬', '익히어', '날', '마다', '쓰는', '데', '편하게', '할', '뿐', '이다', '.']
# nouns():
#  ['나랏말', '중국', '달라', '한자', '서로', '통', '우매', '백성', '말', '것', '마침내', '제', '뜻', '표현', '사람', '내', '스물', '여덟', '사람', '쉬', '날', '데', '뿐']
# phrases():
#  ['나랏말', '중국', '중국과 달라', '중국과 달라 한자', '중국과 달라 한자와 서로', '중국과 달라 한자와 서로 통', '우매', '백성들', '마침내', '마침내 제', '마침내 제 뜻', '표현', '못하는 사람', '스물여덟', '사람들', '달라', '한자', '서로', '사람', '스물', '여덟']
# pos():
#  [('나랏말', 'Noun'), ('이', 'Josa'), ('중국', 'Noun'), ('과', 'Josa'), ('달라', 'Noun'), ('한자', 'Noun'), ('와', 'Josa'), ('서로', 'Noun'), ('통', 'Noun'), ('하지', 'Verb'), ('아니하므로', 'Adjective'), (',', 'Punctuation'), ('\n', 'Foreign'), ('우매', 'Noun'), ('한', 'Josa'), ('백성', 'Noun'), ('들', 'Suffix'), ('이', 'Josa'), ('말', 'Noun'), ('하고', 'Josa'), ('싶은', 'Verb'), ('것', 'Noun'), ('이', 'Josa'), ('있어도', 'Adjective'), ('마침내', 'Noun'), ('제', 'Noun'), ('뜻', 'Noun'), ('을', 'Josa'), ('잘', 'Verb'), ('표현', 'Noun'), ('하지', 'Verb'), ('못', 'VerbPrefix'), ('하는', 'Verb'), ('사람', 'Noun'), ('이', 'Josa'), ('많다', 'Adjective'), ('.', 'Punctuation'), ('\n', 'Foreign'), ('내', 'Noun'), ('이를', 'Verb'), ('딱하게', 'Adjective'), ('여기어', 'Verb'), ('새로', 'Adjective'), ('스물', 'Noun'), ('여덟', 'Noun'), ('자를', 'Verb'), ('만들었으니', 'Verb'), (',', 'Punctuation'), ('\n', 'Foreign'), ('사람', 'Noun'), ('들', 'Suffix'), ('로', 'Josa'), ('하여금', 'Adverb'), ('쉬', 'Noun'), ('익히어', 'Verb'), ('날', 'Noun'), ('마다', 'Josa'), ('쓰는', 'Verb'), ('데', 'Noun'), ('편하게', 'Adjective'), ('할', 'Verb'), ('뿐', 'Noun'), ('이다', 'Josa'), ('.', 'Punctuation')]

# %%
stopwords = ['및', '주요업무', '업무'] # wordcloud에서 제외할 단어

print(f'sector_list len: {len(main_task)}')
make_wordcloud(main_task, stopwords, 50,image1='working.png')
# Out:
# sector_list len: 55360
# --------------------------------------------------------------------------------
# tag_dict: {'개발': 2037, '서비스': 914, '데이터': 751, '관리': 627, '운영': 606, '기술': 604, '설계': 600, '시스템': 556, '등': 464, '기반': 455, '개선': 434, '팀': 415, '위': 406, '수': 404, '구축': 361, '분석': 329, '테스트': 322, '유지': 318, '환경': 315, '최적화': 315, '를': 294, '활용': 264, '모델': 263, '진행': 260, '기능': 259, '고객': 258, '보수': 255, '플랫폼': 248, '성능': 248, '백엔드': 244, '구현': 239, '제품': 238, '지원': 233, '인프라': 222, '솔루션': 212, '웹': 206, '통해': 196, '수행': 196, '사용자': 191, '앱': 186, '코드': 178, '처리': 173, '자동화': 173, '보안': 171, '경험': 169, '효율': 166, '해결': 166, '대한': 165}

# %%
make_wordcloud(prefered, stopwords, 50)
# Out:
# --------------------------------------------------------------------------------
# tag_dict: {'경험': 3042, '분': 2642, '우대': 1121, '개발': 1082, '사항': 1036, '등': 735, '대한': 583, '서비스': 552, '관련': 429, '운영': 410, '이해': 347, '기술': 342, '데이터': 316, '보유': 308, '수': 304, '사용': 293, '활용': 290, '환경': 284, '시스템': 258, '기반': 255, '설계': 243, '구축': 238, '프로젝트': 201, '능력': 196, '업무': 194, '처리': 186, '관심': 183, '테스트': 168, '를': 168, '클라우드': 163, '협업': 158, '해결': 156, '분석': 152, '관리': 146, '코드': 145, '커뮤니케이션': 143, '자동화': 143, '문제': 141, '위': 140, '최적화': 139, '팀': 137, '경력': 136, '개선': 133, '지원': 132, '더': 116, '배포': 116, '지식': 115, '이상': 112, '웹': 108}

# %%
stopwords=['분','요건','자격','이상','경험','개발','자격요건','대한','경력','이해',
           '보유','능력','사용','서비스','운영','활용','설계','관련','기반','기술','관리',
           '문제','환경','해결','협업','역량','지식','업무']
make_wordcloud_ph(required, stopwords, 100)
# Out:
# --------------------------------------------------------------------------------
# tag_dict: {'데이터': 264, '3년': 254, 'React': 237, 'Python': 210, '커뮤니케이션': 203, 'API': 199, '시스템': 196, 'js': 196, '5년': 189, '백엔드': 187, 'AWS': 186, '언어': 178, 'Java': 175, '분석': 158, '프로젝트': 156, 'Spring': 148, '프레임워크': 147, '구축': 139, '프로그래밍': 136, '코드': 133, '테스트': 131, 'Git': 129, 'AI': 116, '클라우드': 114, '도구': 111, '실무': 110, '2년': 110, '이용': 109, '이해도': 109, '경험자': 108, '분야': 103, '데이터베이스': 103, '프론트엔드': 102, '작성': 101, '구현': 96, '전공': 92, '공학': 91, '배포': 91, '컴퓨터': 87, '최적화': 87, 'MySQL': 87, 'CSS': 86, 'Kotlin': 84, '필수': 82, 'JavaScript': 79, 'TypeScript': 79, '보안': 77, 'HTML': 76, '네트워크': 76, '학력': 76, '개선': 76, '학사': 75, '모델': 74, 'SQL': 74, 'Typescript': 74, '통한': 74, '처리': 73, 'Node': 72, '스택': 71, '관심': 71, '서버': 70, '러닝': 70, '인프라': 69, 'RDBMS': 68, 'CD': 68, '학습': 66, 'RESTful': 66, 'Vue': 66, 'CI': 63, '제품': 63, '자동화': 62, '소프트웨어': 62, '대해': 61}

# %%
stopwords = ['사내','성장','사용','운영','제도','및', '지원', '제공', '복지', '수', '비','등','시','채용','위','팀','혜택','지급','업무','근무']
# stopwords = []
make_wordcloud_ph(benefit,stopwords, 50, image1='cup.png')
# Out:
# --------------------------------------------------------------------------------
# tag_dict: {'휴가': 1281, '연차': 615, '선물': 557, '도서': 543, '생일': 532, '건강검진': 487, '문화': 480, '교육': 471, '간식': 458, '명절': 443, '식대': 437, '환경': 434, '회사': 426, '개인': 404, '위해': 389, '자율': 386, '장비': 380, '서류': 378, '관련': 373, '야근': 367, '점심': 365, '시간': 351, '무제한': 346, '비용': 336, '직원': 327, '경조사': 314, '직무': 310, '진행': 308, '경우': 307, '출근': 305, '보험': 303, '출퇴근': 283, '반차': 279, '커피': 278, '건강': 276, '축하': 264, '장기': 257}

# %%
stopwords = ['사내','성장','사용','운영','제도','및', '지원', '제공', '복지', '수', '비','등','시','채용','위','팀','혜택','지급','업무','근무']
# stopwords = []
make_wordcloud_ph(benefit,stopwords, 50, image1='cup.png')
# Out:
# --------------------------------------------------------------------------------
# tag_dict: {'휴가': 1281, '연차': 615, '선물': 557, '도서': 543, '생일': 532, '건강검진': 487, '문화': 480, '교육': 471, '간식': 458, '명절': 443, '식대': 437, '환경': 434, '회사': 426, '개인': 404, '위해': 389, '자율': 386, '장비': 380, '서류': 378, '관련': 373, '야근': 367, '점심': 365, '시간': 351, '무제한': 346, '비용': 336, '직원': 327, '경조사': 314, '직무': 310, '진행': 308, '경우': 307, '출근': 305, '보험': 303, '출퇴근': 283, '반차': 279, '커피': 278, '건강': 276, '축하': 264, '장기': 257}

# %%
fitSR = pd.Series({'휴가': 1281, '연차': 615, '선물': 557, '도서': 543, '생일': 532, '건강검진': 487, '문화': 480, '교육': 471, '간식': 458, '명절': 443, '식대': 437, '환경': 434, '회사': 426, '개인': 404, '위해': 389, '자율': 386, '장비': 380, '서류': 378, '관련': 373, '야근': 367, '점심': 365, '시간': 351, '무제한': 346, '비용': 336, '직원': 327, '경조사': 314, '직무': 310, '진행': 308, '경우': 307, '출근': 305, '보험': 303, '출퇴근': 283, '반차': 279, '커피': 278, '건강': 276, '축하': 264, '장기': 257})
fitSR
# Out:
# 휴가      1281
# 연차       615
# 선물       557
# 도서       543
# 생일       532
# 건강검진     487
# 문화       480
# 교육       471
# 간식       458
# 명절       443
# 식대       437
# 환경       434
# 회사       426
# 개인       404
# 위해       389
# 자율       386
# 장비       380
# 서류       378
# 관련       373
# 야근       367
# 점심       365
# 시간       351
# 무제한      346
# 비용       336
# 직원       327
# 경조사      314
# 직무       310
# 진행       308
# 경우       307
# 출근       305
# 보험       303
# 출퇴근      283
# 반차       279
# 커피       278
# 건강       276
# 축하       264
# 장기       257
# dtype: int64

# %%
fitSR_sorted = fitSR.sort_values()

# %%
fitSR_sorted.shape
# Out:
# (37,)

# %%
# %pip install squarify
import squarify  # 트리맵 라이브러리

# 데이터 생성
# 트리맵 그리기
plt.figure(figsize=(4, 4))
squarify.plot(fitSR_sorted[17:], 
              label=fitSR_sorted.index[17:], alpha=0.7, 
              color=plt.cm.Spectral(np.linspace(0, 1, len(fitSR_sorted)))[::-1]
              )

# 그래프 설정
plt.axis('off')  # 축 제거

plt.show()

# %%
sceDF = pd.DataFrame(pd.read_csv('source.csv', index_col=0))

# %%
sce_list = sceDF['포지션'].tolist()

# %%
stopwords = [ '개발', '이상','팀','요원','가능','및','기능','리더','트','부']
make_wordcloud(sce_list,stopwords,50,image1='working.png')
# Out:
# --------------------------------------------------------------------------------
# tag_dict: {'개발자': 1091, '엔지니어': 473, '백엔드': 393, '프론트엔드': 251, '플랫폼': 112, '서비스': 104, '웹': 102, '데이터': 100, '솔루션': 80, '시스템': 79, '시니어': 75, '서버': 75, '운영': 72, '담당자': 72, '소프트웨어': 69, '보안': 67, '풀': 64, '스택': 64, '앱': 62, '기술': 56, '분석': 53, '신입': 53, '병역': 47, '특례': 47, '리드': 39, '사업': 39, '지원': 38, '주니어': 37, '본부': 37, '블록': 36, '체인': 36, '클라우드': 35, '연구원': 34, '인프라': 33, '러닝': 30, '근무': 30, '모바일': 29, '연구': 29, '펌웨어': 28, '일본': 28, '보충역': 27, '하드웨어': 26, '머신': 25, '쿠팡': 25}

# %%
sceDF['지역명'].unique()
# Out:
# array(['서울 구로구 ', '서울 마포구 ', '서울 금천구 ', '울산 중구 ', '서울 강남구 ', '서울 서초구 ',
#        '서울 중구 ', '경기 성남시 ', '경기 화성시 ', '서울 영등포구 ', '서울 성동구 ', '대전 유성구 ',
#        '서울 송파구 ', '서울 종로구 ', '서울 관악구 ', '경기 의왕시 ', '경기 안양시 ', '인천 서구 ',
#        '경기 용인시 ', '서울 ', '경기 고양시 ', '서울 강서구 ', '충북 청주시 ', '서울 용산구 ',
#        '경기 ', '경기 과천시 ', '부산 부산진구 ', '제주 제주시 ', '서울 도봉구 ', '서울 광진구 ',
#        '광주 북구 ', '서울 동작구 ', '서울 서대문구 ', '인천 연수구 ', '충남 천안시 ', '대구 북구 ',
#        '부산 해운대구 ', '경기 군포시 ', '대구 남구 ', '경기 포천시 ', '대전 서구 ', '경기 광명시 ',
#        '서울 강동구 ', '경기 하남시 ', '부산 ', '서울 동대문구 ', '경북 포항시 ', '인천 부평구 ',
#        '경기 파주시 ', '부산 북구 ', '대구 수성구 ', '경기 수원시 ', '경기 남양주시 ', '경기 안산시 ',
#        '서울 노원구 ', '충남 아산시 ', '경기 김포시 ', '대구 동구 ', '충남 공주시 ', '세종 ',
#        '경기 광주시 ', '경북 안동시 ', '경남 창원시 ', '전북 군산시 ', '부산 영도구 ', '인천 계양구 ',
#        '경기 부천시 ', '경기 평택시 ', '대구 서구 ', '경기 시흥시 '], dtype=object)

# %%
region_list = sceDF['지역명'].tolist()
stopwords = []
make_wordcloud(region_list,stopwords,50, image1='southkorea.png' ,colormap1='inferno')
# Out:
# --------------------------------------------------------------------------------
# tag_dict: {'서울': 2611, '강남구': 1155, '경기': 496, '서초구': 327, '성남시': 318, '마포구': 167, '성동구': 156, '영등포구': 130, '중구': 117, '송파구': 114, '금천구': 81, '구로구': 79, '용산구': 63, '종로구': 52, '관악구': 51, '강서구': 42, '안양시': 37, '대전': 33, '유성구': 31, '인천': 29, '용인시': 28, '연수구': 25, '수원시': 20, '과천시': 18, '부산': 14, '광진구': 13, '화성시': 12, '충남': 11, '해운대구': 8, '동대문구': 8, '경북': 8, '고양시': 7, '천안시': 7, '군포시': 7, '대구': 6, '강동구': 6, '포항시': 6, '부천시': 6, '서구': 4, '서대문구': 4, '광명시': 4, '남양주시': 4, '울산': 3, '부산진구': 3, '북구': 3, '동작구': 3, '파주시': 3, '안산시': 3, '아산시': 3, '도봉구': 2}

# %%
for i in range(len(region_list)):
    region_list[i] = region_list[i][:2]
sidoSR = pd.Series(region_list)
sidoSR.value_counts()
# Out:
# 서울    2611
# 경기     496
# 대전      33
# 인천      29
# 부산      14
# 충남      11
# 경북       8
# 대구       6
# 울산       3
# 충북       1
# 제주       1
# 광주       1
# 세종       1
# 경남       1
# 전북       1
# Name: count, dtype: int64

# %%
top3_values = sidoSR.value_counts()[:3]
top3_labels = top3_values.index

cmap = plt.cm.Set1

plt.pie(top3_values, 
        labels=top3_labels,  
        autopct='%1.1f%%', 
        startangle=0, 
        colors=cmap(range(len(top3_values))),  
        textprops={'color': 'white', 'fontsize': 12, 'fontweight': 'bold'},
        wedgeprops={'edgecolor': 'black', 'linewidth': 1, 'linestyle': 'solid', 'antialiased': True},
        pctdistance=0.75) 

centre_circle = plt.Circle((0, 0), 0.50, fc='white', edgecolor="black")  
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.legend(top3_labels, loc="best") 

plt.axis('equal')  

plt.title("채용공고 지역별 Top 3")
plt.show()

# %%
sceDF['경력'].unique()
# Out:
# array([' 신입-경력 6년', ' 경력 5-10년', ' 경력 10년 이상', ' 경력 3-15년', ' 신입',
#        ' 경력 3년 이상', ' 경력 3-10년', ' 경력 3-6년', ' 경력 3-16년', ' 경력 4-10년',
#        ' 경력 5-15년', ' 경력 4-8년', ' 경력 5년 이상', ' 경력 2-7년', ' 신입-경력 5년',
#        ' 경력 2-5년', ' 경력 6-20년', ' 신입-경력 8년', ' 경력 3-5년', ' 신입-경력 20년',
#        ' 경력 3-25년', ' 경력 6-10년', ' 경력 2-6년', ' 경력 1-6년', ' 경력 2년 이상',
#        ' 경력 7-15년', ' 경력 3-8년', ' 경력 7년 이상', ' 경력 4-20년', ' 경력 3-7년',
#        ' 경력 7-10년', ' 경력 1-3년', ' 경력 1-10년', ' 경력 3년', ' 경력 3-12년',
#        ' 경력 1년 이상', ' 경력 5-12년', ' 신입-경력 10년', ' 경력 8-12년', ' 경력 10-20년',
#        ' 경력 5-13년', ' 경력 4-11년', ' 경력 8-20년', ' 경력 7-17년', ' 경력 7-20년',
#        ' 경력 10-15년', ' 경력 8년', ' 경력 10년', ' 경력 10-30년', ' 경력 2-15년',
#        ' 경력 4-7년', ' 경력 1-5년', ' 경력 2-8년', ' 경력 8년 이상', ' 경력 1-7년',
#        ' 경력 4년 이상', ' 경력 7-12년', ' 경력 4-12년', ' 경력 10-13년', ' 경력 1-4년',
#        ' 경력 5-20년', ' 경력 1-15년', ' 경력 9년 이상', ' 경력 5-8년', ' 경력 2-10년',
#        ' 경력 3-20년', ' 신입-경력 3년', ' 경력 3-11년', ' 신입-경력 2년', ' 경력 6-12년',
#        ' 신입 이상', ' 경력 7-9년', ' 경력 6년 이상', ' 경력 2-13년', ' 경력 5-7년',
#        ' 경력 4-6년', ' 경력 1-12년', ' 경력 4-15년', ' 경력 5-16년', ' 경력 5-14년',
#        ' 신입-경력 12년', ' 경력 2-4년', ' 경력 1-8년', ' 경력 2-12년', ' 경력 7-13년',
#        ' 경력 2-3년', ' 경력 12년 이상', ' 경력 6-8년', ' 경력 2-9년', ' 경력 6-15년',
#        ' 경력 10-25년', ' 경력 5-6년', ' 경력 5-35년', ' 경력 6-14년', ' 경력 8-15년',
#        ' 신입-경력 7년', ' 신입-경력 4년', ' 경력 6-9년', ' 경력 12-15년', ' 경력 8-10년',
#        ' 경력 3-13년', ' 경력 3-4년', ' 경력 5-9년', ' 경력 5-11년', ' 경력 2-20년',
#        ' 경력 1-20년', ' 경력 9-20년', ' 경력 2-16년', ' 경력 2-25년', ' 경력 5-50년',
#        ' 경력 15-20년', ' 경력 7-8년', ' 경력 5년', ' 경력 15년 이상', ' 경력 2년',
#        ' 경력 9년', ' 경력 7-14년', ' 경력 10-19년', ' 신입-경력 15년', ' 경력 5-17년',
#        ' 경력 8-17년', ' 경력 10-23년', ' 경력 25-35년', ' 경력 7-11년', ' 경력 10-12년',
#        ' 경력 8-11년', ' 경력 5-25년', ' 경력 3-9년', ' 경력 1-2년', ' 경력 9-15년',
#        ' 경력 4-14년', ' 경력 3-14년', ' 경력 12-17년', ' 경력 3-30년', ' 경력 5-18년',
#        ' 경력 6-13년', ' 신입-경력 9년', ' 경력 4-18년', ' 경력 7-25년', ' 경력 8-16년',
#        ' 경력 3-18년', ' 경력 15-19년', ' 경력 4-5년', ' 경력 8-25년', ' 경력 6년',
#        ' 경력 1년', ' 경력 10-18년', ' 경력 3-26년', ' 경력 7년', ' 경력 1-16년',
#        ' 경력 8-30년', ' 경력 3-17년', ' 경력 2-30년', ' 경력 10-16년', ' 신입-경력 30년',
#        ' 경력 7-18년', ' 경력 2-14년', ' 경력 4년', ' 경력 8-13년', ' 경력 4-17년',
#        ' 경력 4-9년', ' 경력 1-13년', ' 경력 4-28년', ' 경력 5-30년', ' 경력 1-9년'],
#       dtype=object)

# %%
years_list = sceDF['경력'].tolist()
stopwords = []
make_wordcloud(years_list,stopwords,50, 'magma')
# Out:
# --------------------------------------------------------------------------------
# tag_dict: {'경력': 3045, '이상': 888, '신입': 371}

# %%
sceDF['경력']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 sceDF['경력']
#
# NameError: name 'sceDF' is not defined

# %%
f_main_task = list()
make_list('f_main_task.txt', f_main_task)
# Out:
# f_main_task.txt
# ['주요업무',
#  '번역엔진',
#  '학습,',
#  '성능',
#  '개선,',
#  '도메인/언어',
#  '확장',
#  'Neural',
#  'Machine',
#  'Translation',
#  '(NMT)',
#  '성능',
#  '개선을',
#  '위한',
#  '리서치',
#  '및',
#  '엔지니어링',
#  'NMT',
#  '관련',
#  '분야',
#  '최신',
#  '기술',
#  '(Quality',
#  'Estimation,',
#  'Automatic',
#  'Post',
#  'Editing,',
#  'Word',
#  'Alignment,',
#  'etc.)',
#  '모델',
#  '개발,',
#  '성능',
#  '개선을',
#  '위한',
#  '실험',
#  '및',
#  '엔지니어링',
#  '주요업무',
#  '번역의',
#  '의뢰부터',
#  '진행/검수/납품/결제까지의',
#  '전',
#  '단계를',
#  '커버하는',
#  '번역',
#  '서비스',
#  '플랫폼을',
#  '만듭니다.',
#  '주요업무',
#  '담당',
#  '업무',
#  'DataSpace',
#  '플랫폼',
#  '설계',
#  '및',
#  '아키텍쳐',
#  '정의',
#  'DataSpace',
#  '플랫폼',
#  '상세',
#  '서비스',
#  '설계',
#  'B2B',
#  '마켓플레이스',
#  '플랫폼',
#  '설계',
#  '검색(SEO),',
#  '추천',
#  '시스템,',
#  '트랜잭션',
#  '설계',
#  '등',
#  '플랫폼',
#  '핵심',
#  '기능',
#  '설계',
#  '데이터',
#  '거래',
#  '중심의',
#  '비즈니스',
#  '프로세스',
#  '최적화서비스',
#  '아키텍처',
#  '설계',
#  '결제',
#  '및',
#  '트랜잭션',
#  '관리',
#  '시스템',
#  '설계',
#  '및',
#  '운영',
#  '데이터',
#  '기반',
#  '고객',
#  '맞춤형',
#  '솔루션',
#  '설계',
#  '디지털',
#  '자산',
#  '거래',
#  '솔루션',
#  '설계',
#  '및',
#  '운영Data',
#  'Space',
#  'R&D',
#  '팀',
#  '리더십',
#  '팀',
#  '빌딩',
#  '및',
#  '조직화',
#  '효율적인',
#  '개발',
#  '환경',
#  '및',
#  '인프라',
#  '구축',
#  '주요업무',
#  '생성형',
#  'AI',
#  '모델을',
#  '사용하여',
#  '이미지/영상',
#  '합성',
#  '데이터',
#  '생성',
#  '(synthetic',
#  'data',
#  'generation)',
#  '로봇과',
#  '설비의',
#  '물리세계를',
#  '모사하는',
#  '시뮬레이션',
#  '모델',
#  '설계',
#  '(공간관계,',
#  '물리적',
#  '규칙)',
#  '로봇,',
#  '설비가',
#  '물리',
#  '세계를',
#  '인지,',
#  '이해,',
#  '추론하여',
#  '자율적으로',
#  '행동할',
#  '수',
#  '있도록',
#  '가상',
#  '시뮬레이션',
#  '환경에서',
#  '강화',
#  '학습을',
#  '이용하여',
#  '최적의',
#  'action',
#  'policy',
#  '훈련',
#  'Digital',
#  'Twin',
#  '&',
#  'Simulation',
#  '엔지니어,',
#  'Robotics',
#  '엔지니어와',
#  '협업',
#  '주요업무AI',
#  'Model',
#  'Optimization',
#  '모델',
#  '압축(양자화,',
#  '프루닝',
#  '등),',
#  '연산자',
#  '퓨전,',
#  '메모리',
#  '최적화',
#  '기법을',
#  '활용하여',
#  '모델',
#  '성능',
#  '개선',
#  '및',
#  '모델',
#  '추론',
#  '속도',
#  '향상',
#  'CPU/GPU/NPU등',
#  'HW를',
#  '고려한',
#  'AI모델',
#  '최적화',
#  '기법',
#  '개발',
#  '필요한',
#  'AI',
#  '모듈(예:',
#  '객체',
#  '인식,',
#  '이상',
#  '탐지',
#  '등)을',
#  '최적화하여',
#  '실시간',
#  '실행',
#  '성능',
#  '확보',
#  'AI',
#  '모델',
#  '병렬화',
#  '및',
#  '분산',
#  '실행',
#  '기술',
#  '적용Tool',
#  '체인',
#  '개발',
#  'AI',
#  '모델',
#  '변환',
#  '및',
#  '최적화를',
#  '위한',
#  '툴체인',
#  '설계',
#  '및',
#  '구현신기술',
#  '리서치',
#  '및',
#  '연구',
#  'AI',
#  '및',
#  'Hardware',
#  '가속기',
#  '관련',
#  '최신',
#  '기술',
#  '및',
#  '연구',
#  '동향',
#  '분석',
#  '주요업무',
#  'Databricks',
#  '환경에서',
#  'Spark',
#  'SQL',
#  '및',
#  'PySpark를',
#  '활용한',
#  '데이터',
#  '파이프라인',
#  '설계',
#  '및',
#  '구현',
#  '서비스',
#  '로그',
#  '및',
#  '유저',
#  '이벤트',
#  '데이터',
#  '수집,',
#  '가공,',
#  '적재',
#  '프로세스',
#  '구축',
#  '전사',
#  '데이터',
#  '마트',
#  '설계',
#  '및',
#  '운영',
#  '데이터',
#  '크롤링',
#  '시스템',
#  '구축',
#  '및',
#  '운영',
#  'ML/AI',
#  '팀과',
#  '협업하여',
#  '모델',
#  '서빙',
#  '파이프라인',
#  '구축',
#  'A/B',
#  '테스트',
#  '등',
#  '실험',
#  '환경',
#  '구축',
#  '및',
#  '운영',
#  '주요업무본',
#  '포지션은',
#  'EQST(화이트해커',
#  '그룹)',
#  'Lab에서',
#  '근무합니다.',
#  'AI',
#  'LLM',
#  '취약점',
#  '분석',
#  '및',
#  '대응',
#  '방안',
#  '연구',
#  'AI',
#  'LLM',
#  '기반',
#  '서비스',
#  '보안',
#  '평가',
#  '기준',
#  '수립',
#  'AI',
#  'LLM',
#  '서비스',
#  '보안성',
#  '진단',
#  '및',
#  '취약점',
#  '점검',
#  '주요업무',
#  '고객',
#  '시스템에서',
#  '발생하는',
#  '장애나',
#  '성능',
#  '이슈를',
#  '더',
#  '쉽고',
#  '빠르게',
#  '해결하는데',
#  '도움을',
#  '주는',
#  '서비스를',
#  '개발합니다.',
#  '모니터링',
#  '데이터',
#  '중',
#  'Time',
#  'Series',
#  '데이터에',
#  '대한',
#  '이상탐지(Anomaly',
#  'Detection)',
#  '방법을',
#  '연구하여',
#  '적용합니다.',
#  '모니터링',
#  '데이터를',
#  '기반으로',
#  '머신',
#  '러닝(ML)',
#  '활용',
#  '방안',
#  '연구하여',
#  '적용',
#  '합니다.',
#  '모니터링',
#  '플렛폼에서',
#  'Generative',
#  'AI',
#  '활용방안을',
#  '연구하여',
#  '적용합니다.',
#  '주요업무',
#  '영상,',
#  '빅데이터기반',
#  'AI모델',
#  '개발/튜닝',
#  '제품',
#  '서비스를',
#  '위한',
#  'AI',
#  '파이프라인',
#  '구축',
#  '및',
#  '자동화',
#  '주요업무',
#  '영상',
#  '인식',
#  '알고리즘',
#  '개발',
#  '엔지니어',
#  '(신입/경력)',
#  '주요업무',
#  '제조업',
#  '관련',
#  '프로젝트',
#  '기획',
#  '/',
#  '수행',
#  '제조',
#  '데이터(센서',
#  '데이터,',
#  '공정',
#  '데이터',
#  '등)',
#  '기반의',
#  '분석',
#  '및',
#  '모델',
#  '개발',
#  '실시간',
#  '및',
#  '배치',
#  '데이터',
#  '처리',
#  '파이프라인',
#  '구축',
#  '머신러닝',
#  '모델의',
#  '서빙',
#  '및',
#  '성능',
#  '개선',
#  '작업',
#  '주요업무',
#  '이런',
#  '업무를',
#  '담당합니다.',
#  '1.',
#  '머신러닝',
#  '기반의',
#  '백엔드',
#  '어플리케이션',
#  '설계',
#  '및',
#  '구현',
#  '뤼이드에서',
#  '우리는',
#  '지식의',
#  '추적,',
#  '실시간',
#  '성적',
#  '예측등의',
#  '교육',
#  '분야에서',
#  '머신러닝',
#  '모델들을',
#  '적극적으로',
#  '활용하고',
#  '있습니다.',
#  '특히',
#  '최근에는',
#  'LLM',
#  '과',
#  'TTS',
#  '기술들',
#  '같은',
#  '모델',
#  '배포도',
#  '진행하고',
#  '있습니다.',
#  '뤼이드의',
#  'MLOps',
#  'Engineer',
#  '로서',
#  '산타토익,',
#  '산타세이,',
#  'A:IR',
#  'Math',
#  '등',
#  '뤼이드의',
#  '다양한',
#  '서비스에서',
#  '머신러닝을',
#  '통합할',
#  '수',
#  '있도록',
#  'Backend',
#  'Application',
#  '을',
#  '개발합니다.',
#  '2.',
#  '모델',
#  '추론을',
#  '위한',
#  '데이터',
#  '파이프라인',
#  '개발',
#  '사용자들의',
#  '실시간',
#  '상호작용',
#  '데이터를',
#  '모델',
#  '추론,',
#  '성능',
#  '분석,',
#  '서비스',
#  '지표로',
#  '활용하기',
#  '위해',
#  '고도화된',
#  '데이터',
#  '파이프라인(Airflow,',
#  'Databricks)의',
#  '개발을',
#  '담당합니다.',
#  'Backend',
#  'Application에서',
#  '활용',
#  '가능한',
#  'Feature',
#  'Store를',
#  '설계',
#  '및',
#  '구현하며',
#  '서비스',
#  '지표와',
#  '모델',
#  '성능을',
#  '강화할',
#  '수',
#  '있는',
#  '다양한',
#  '특징들을',
#  '발굴하고',
#  '최적화합니다.3.',
#  '모델',
#  '학습을',
#  '위한',
#  '파이프라인',
#  '및',
#  '인프라',
#  '운영',
#  'ML',
#  'Engineer는',
#  '사내에',
#  '있는',
#  '다양한',
#  'GPU',
#  '자원을',
#  '활용해',
#  '학습을',
#  '자동화하고',
#  '연속적인',
#  '학습',
#  '파이프라인을',
#  '개발',
#  '및',
#  '최적화',
#  '합니다.',
#  '주요업무',
#  'Azure',
#  '및',
#  '클라우드',
#  '기반',
#  '생성형',
#  'AI',
#  '솔루션',
#  '개발',
#  '웹',
#  '앱,',
#  'Teams',
#  '앱',
#  '및',
#  '플러그인',
#  '개발을',
#  '통해',
#  '비즈니스',
#  '프로세스와',
#  '협업',
#  '도구를',
#  'AI로',
#  '강화',
#  'Copilot',
#  'Studio와',
#  'Azure',
#  'AI',
#  'Studio를',
#  '사용하여',
#  '맞춤형',
#  'AI',
#  '어플리케이션',
#  '설계',
#  '및',
#  '개발.',
#  '주요업무',
#  '검색',
#  '추천',
#  '등',
#  '사용자',
#  '경험에서',
#  '발생하는',
#  '주요',
#  '결함의',
#  '근본',
#  '원인',
#  '분석',
#  '가장',
#  '최적의',
#  '기술',
#  '(ML,',
#  'DL,',
#  'LLM',
#  '등)을',
#  '활용한',
#  '문제',
#  '해결',
#  '방안',
#  '제안',
#  '및',
#  '구현',
#  '머신러닝',
#  '모델의',
#  '개발부터',
#  '프로덕션',
#  '배포까지',
#  '자동화된',
#  '프로세스',
#  '설계',
#  '및',
#  '구현',
#  '시뮬레이션',
#  '및',
#  'A/B',
#  '테스트를',
#  '설계하고',
#  '분석',
#  '결과',
#  '기반',
#  '개선점',
#  '도출',
#  '및',
#  '개선',
#  '주니어',
#  'MLE',
#  '멘토링을',
#  '통한',
#  '팀',
#  'ML',
#  '역량',
#  '강화',
#  '조직',
#  '내',
#  '합의를',
#  '이끌고',
#  '기술적',
#  '비전을',
#  '공유하는',
#  '리더',
#  '역할',
#  '주요업무',
#  'Streaming',
#  'data',
#  'pipeline',
#  '구축,',
#  'stream',
#  '처리',
#  '작업',
#  '개발',
#  '및',
#  '운영',
#  'A/B',
#  'testing',
#  '플랫폼의',
#  '데이터',
#  '수집,',
#  '정합성',
#  '관리',
#  'Data',
#  '적재',
#  '작업',
#  '개발,',
#  '정합성',
#  '관리',
#  '및',
#  '운영',
#  'Data',
#  'Platform',
#  '개선',
#  '및',
#  '운영',
#  'Data',
#  'Warehouse',
#  '및',
#  'Data',
#  'Mart',
#  '모델링',
#  '주요업무',
#  '자연어',
#  '처리(NLP)',
#  '기술을',
#  '활용한',
#  '검색',
#  '순위',
#  '모델(Ranking',
#  'Model)',
#  '개발',
#  '질의어',
#  '분석을',
#  '통한',
#  '검색',
#  '의도',
#  '이해(Query',
#  'Understanding)',
#  '글로벌',
#  '서비스를',
#  '위한',
#  '다국어',
#  '언어',
#  '분석기',
#  '개선',
#  '토픽',
#  '모델링,',
#  '키워드',
#  '확장,',
#  '시맨틱',
#  '검색',
#  '등',
#  '검색',
#  '관련',
#  'NLP',
#  '기술',
#  '연구',
#  '및',
#  '적용',
#  '검색',
#  '품질',
#  '지표',
#  '정의',
#  '및',
#  'A/B',
#  '테스트를',
#  '통한',
#  '성능',
#  '평가',
#  '주요업무',
#  '보다',
#  '나은',
#  '사용자',
#  '경험을',
#  '위한',
#  'Java,',
#  'Spring',
#  'Framework',
#  '기반의',
#  '자사',
#  '솔루션',
#  '개발',
#  '및',
#  '유지보수',
#  '코드',
#  '리뷰와',
#  '테스트를',
#  '통해',
#  '코드',
#  '품질',
#  '유지',
#  '주요업무',
#  'AI',
#  '기반',
#  'NLP,',
#  '멀티모달',
#  '서비스',
#  '개발',
#  '고객사',
#  '데이터',
#  '분석',
#  '및',
#  '딥러닝',
#  '모델',
#  '학습',
#  'Task와',
#  'Dataset에',
#  '맞게',
#  '최적화된',
#  '학습법',
#  '연구',
#  '및',
#  '설계',
#  'Vision',
#  '등의',
#  '멀티모달',
#  '서비스를',
#  '위한',
#  '모델',
#  '연구',
#  '및',
#  '설계',
#  '기존',
#  '자사',
#  '제품과',
#  '연계된',
#  '딥러닝',
#  '모델',
#  '개발',
#  'LLM',
#  '기반',
#  'AI',
#  '서비스',
#  '개발',
#  '오픈소스',
#  'LLM을',
#  '기반으로',
#  '한',
#  '자체',
#  'LLM',
#  '구축',
#  'LLM',
#  'Fine',
#  'tuning',
#  '및',
#  'Prompt',
#  'Engineering을',
#  '위한',
#  '데이터',
#  '구축',
#  '및',
#  '연구',
#  '기존',
#  '자사',
#  '제품과',
#  '연계된',
#  'LLM',
#  '모델',
#  '개발',
#  'AI',
#  '데이터셋',
#  '자동',
#  '가공',
#  '모듈',
#  '대용량의',
#  'AI',
#  'Data를',
#  '자동으로',
#  '분류,',
#  '비식별화',
#  '및',
#  '증강하는',
#  'AI',
#  '데이터',
#  '전처리',
#  '주요업무',
#  '다국어/다감정/다화자/소용량',
#  'TTS',
#  '모델',
#  '개발',
#  '및',
#  '성능개선',
#  'ONNX/TensorRT를',
#  '이용한',
#  '인퍼런스',
#  '고속화',
#  '엔진',
#  '개발',
#  '주요업무',
#  'CNN,',
#  'GAN',
#  '기반',
#  'Word/Character',
#  'Detection',
#  '딥러닝',
#  '기술',
#  '개발',
#  'CNN기반',
#  'Word/Character',
#  'Recognition',
#  '딥러닝',
#  '기술',
#  '개발',
#  'CNN,',
#  'GAN기반',
#  'ROI',
#  'Detection',
#  '기술',
#  '개발',
#  'CNN',
#  '기반',
#  'Frequency',
#  'Domain',
#  'Image',
#  'Classification',
#  '기술',
#  '개발',
#  'C/C++',
#  '엔진',
#  '학습',
#  '모델',
#  '동작',
#  '엔진',
#  '개발',
#  'OpenCV',
#  '기반',
#  '영상',
#  '처리',
#  '기술',
#  '개발',
#  'onnxruntime',
#  '기반',
#  'inference',
#  '코드',
#  '개발',
#  '주요업무',
#  'Mission',
#  'of',
#  'the',
#  'role',
#  'STRADVISION의',
#  'Data',
#  'Pipeline',
#  'Team(이하',
#  'DPT)은',
#  '유능한',
#  '팀원들과',
#  '함께',
#  '데이터',
#  '효율(DE:',
#  'data',
#  'efficiency)/데이터',
#  '품질(DQ:',
#  'data',
#  'quality)',
#  '개선',
#  'Pipeline(이하',
#  'SVflow)',
#  '서비스를',
#  '구축할',
#  'Data',
#  'Pipeline',
#  'Backend',
#  'Engineer을',
#  '모집하고',
#  '있습니다.',
#  'DPT는',
#  'STRADVISION',
#  '내부에서',
#  '데이터',
#  '효율성과',
#  '품질을',
#  '개선하는',
#  '서비스',
#  '개발',
#  '및',
#  '운영을',
#  '담당하는',
#  '부서입니다.',
#  'DPT의',
#  'Data',
#  'Pipeline',
#  'Backend',
#  'Engineer는',
#  '팀',
#  '멤버들과',
#  '협력하여',
#  'SVflow',
#  '서비스에서',
#  '데이터',
#  '변환,',
#  'ML(Machine',
#  'Learning)',
#  '모델의',
#  '배포,',
#  'DE/DQ',
#  'Pipeline',
#  '개발을',
#  '효율적이고',
#  '신뢰성',
#  '있게',
#  '수행하는',
#  '역할을',
#  '맡습니다.',
#  '이',
#  '역할의',
#  '목표는',
#  'ML',
#  '모델',
#  '학습에',
#  '필요한',
#  '데이터',
#  '품질을',
#  '지속적으로',
#  '높이고,',
#  '데이터',
#  '가공',
#  '비용을',
#  '최소화할',
#  '수',
#  '있도록',
#  '지원하는',
#  '것입니다.',
#  '이를',
#  '위해',
#  '최신',
#  'MLOps',
#  '기술의',
#  '능동적인',
#  '습득과',
#  'MLOps',
#  '구현',
#  '및',
#  '적용',
#  '경험이',
#  ...]

# %%
stopwords = ['주요업무','기반','기술','활용','최적화','개발', '이상','팀','요원','가능','및','기능','리더','트','부',
             '관련','고객','수행','통해','대한','제공','진행','배포']

make_wordcloud_ph(f_main_task,stopwords,50,image1='working.png')
# Out:
# --------------------------------------------------------------------------------
# tag_dict: {'데이터': 1179, '모델': 589, 'AI': 563, '설계': 503, '서비스': 480, '분석': 440, '운영': 401, '시스템': 372, '구축': 321, '관리': 307, '연구': 262, '개선': 253, '업무': 214, '알고리즘': 211, '구현': 206, '성능': 204, '솔루션': 190, 'LLM': 182, '파이프라인': 177, '처리': 177, 'API': 173, '러닝': 165, 'and': 164, '환경': 159, '학습': 148, '백엔드': 146, '플랫폼': 137, '제품': 133, '수집': 129, '유지': 119, '자동화': 117, '인프라': 115, '적용': 115, '모니터링': 113, '테스트': 112, 'ML': 111}

# %%
f_required = list()
make_list('f_required.txt', f_required)
stopwords = ['경험', '자격','요건','개발','자격요건','이상','대한','능력','이해','경력','활용','보유','운영',
             '기술','기반','문제','관련','사용','분야','협업','처리']

make_wordcloud_ph(f_required,stopwords,50,image1='cloud.png',colormap1='Spectral')
# Out:
# f_required.txt
# --------------------------------------------------------------------------------
# tag_dict: {'데이터': 537, 'Python': 462, 'AI': 260, '러닝': 255, '분석': 218, '설계': 197, '서비스': 194, '모델': 190, '언어': 184, '해결': 178, '지식': 176, '역량': 166, '환경': 159, '3년': 159, '커뮤니케이션': 159, '딥러닝': 153, '프로그래밍': 152, '업무': 149, '프로젝트': 140, 'SQL': 138, '프레임워크': 131, '학위': 131, '구축': 124, '컴퓨터': 120, '실무': 117, '전공': 114, '백엔드': 112, '머신': 110, '시스템': 108}

# %%
f_benefit = list()
make_list('f_benefit.txt', f_benefit)
stopwords = ['지원','제공','업무','혜택','근무','제도','복지','사용','사내','운영','지급','성장']

make_wordcloud_ph(f_benefit,stopwords,50,image1='cup.png',colormap1='viridis')
# Out:
# f_benefit.txt
# --------------------------------------------------------------------------------
# tag_dict: {'휴가': 946, '도서': 396, '연차': 373, '선물': 352, '생일': 344, '건강검진': 339, '자율': 330, '간식': 322, '교육': 320, '환경': 312, '장비': 289, '문화': 286, '명절': 284, '위해': 266, '직무': 263, '점심': 259, '관련': 257, '야근': 256, '회사': 249, '식대': 245, '시간': 241, '개인': 240, '출근': 238, '비용': 234, '출퇴근': 232, '직원': 223, '무제한': 220, '커피': 214, '보험': 201, '경조사': 186, '반차': 183, '구입': 182, '음료': 175, '최고': 175, '가능': 169, '장기': 168, '리프': 164, '공유': 161}

# %%
filDF = pd.DataFrame(pd.read_csv('filterd_source.csv', encoding='utf-8',index_col=0))

# %%
region_list = filDF['지역명'].tolist()
stopwords = []
make_wordcloud(region_list,stopwords,50, image1='southkorea.png' ,colormap1='inferno')
# Out:
# --------------------------------------------------------------------------------
# tag_dict: {'서울': 646, '강남구': 284, '경기': 109, '서초구': 97, '성남시': 70, '마포구': 49, '성동구': 39, '영등포구': 31, '중구': 27, '송파구': 25, '금천구': 23, '관악구': 17, '종로구': 12, '강서구': 10, '안양시': 9, '구로구': 9, '용산구': 9, '과천시': 7, '용인시': 5, '인천': 5, '연수구': 5, '부산': 4, '충남': 4, '대전': 4, '유성구': 4, '대구': 3, '화성시': 3, '천안시': 3, '부산진구': 2, '남구': 2, '서대문구': 2, '강동구': 2, '수원시': 2, '경북': 2, '포항시': 2, '울산': 1, '북구': 1, '하남시': 1, '파주시': 1, '노원구': 1, '아산시': 1, '해운대구': 1, '안산시': 1, '경남': 1, '창원시': 1, '동작구': 1}

# %%
for i in range(len(region_list)):
    region_list[i] = region_list[i][:2]
sidoSR = pd.Series(region_list)
sidoSR.value_counts()
# Out:
# 서울    646
# 경기    109
# 인천      5
# 부산      4
# 충남      4
# 대전      4
# 대구      3
# 경북      2
# 울산      1
# 경남      1
# Name: count, dtype: int64

# %%
top3_values = sidoSR.value_counts()[:3]
top3_labels = top3_values.index

cmap = plt.cm.Set1

plt.pie(top3_values, 
        labels=top3_labels,  
        autopct='%1.1f%%', 
        startangle=0, 
        colors=cmap(range(len(top3_values))),  
        textprops={'color': 'white', 'fontsize': 12, 'fontweight': 'bold'},
        wedgeprops={'edgecolor': 'black', 'linewidth': 1, 'linestyle': 'solid', 'antialiased': True},
        pctdistance=0.75) 

centre_circle = plt.Circle((0, 0), 0.50, fc='white', edgecolor="black")  
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.legend(top3_labels, loc="best") 

plt.axis('equal')  

plt.title("채용공고 지역별 Top 3")
plt.show()

# %%
filDF['경력'].str.contains('').sum()
# Out:
# 0

# %%
years2 = pd.Series({'신입':139,'경력':710})

top3_values = sidoSR.value_counts()[:3]
top3_labels = years2.index

cmap = plt.cm.Set1

plt.pie(years2, 
        labels=top3_labels,  
        autopct='%1.1f%%', 
        startangle=0, 
        colors=cmap(range(len(top3_values))),  
        textprops={'color': 'white', 'fontsize': 12, 'fontweight': 'bold'},
        wedgeprops={'edgecolor': 'black', 'linewidth': 1, 'linestyle': 'solid', 'antialiased': True},
        pctdistance=0.75) 

centre_circle = plt.Circle((0, 0), 0.50, fc='white', edgecolor="black")  
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.legend(top3_labels, loc="best") 

plt.axis('equal')  

plt.title("관련 직무")
plt.show()
