# %%
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys  import Keys
from selenium.webdriver.common.action_chains import ActionChains
import pandas as pd

# %%
user_id = 'matdongsan5@naver.com'
passwd = 'aktehdtks98!@'

def  login(driver, user_id, pwd):
    driver.get("https://www.jobplanet.co.kr/users/sign_in?_nav=gb")
    time.sleep(1)

    # 아이디 입력
    login_id = driver.find_element(By.ID, "user_email")
    login_id.send_keys(user_id)
    # 비밀번호 입력
    login_pwd = driver.find_element(By.ID, "user_password")
    login_pwd.send_keys(pwd)

    # 로그인 버튼 클릭
    login_id.send_keys(Keys.RETURN)
    time.sleep(5)

# %%
parse = []
ready_count = 0

# %%
def get_page_source(driver):
    if ready_count == 1:
        driver.get('https://www.jobplanet.co.kr/job')
        # driver.switch_to.frame('mainFrame') # 해당 iframe으로 이동
        
        html = driver.page_source
        # soup = BeautifulSoup(html, 'html.parser')
        
        # results = soup.find_all('div', {'class': 'overflow-hidden medium'})
        # print(results)
        
        # return results
        print(html)
    else:
        print('not ready')

# %%
def scroll_all(driver):
    global ready_count
    ready_count = 0
    body = driver.find_element(By.TAG_NAME, "body")
    
    for _ in range(10):  # 10번 페이지 다운
        body.send_keys(Keys.PAGE_DOWN)
        time.sleep(1)
    
    ready_count = 1

# %%
def main():
    global parse
    driver = webdriver.Chrome()

    login(driver, user_id, passwd)
    scroll_all(driver)       
    # time.sleep(5) 
    # parse = get_page_source(driver)
    
    time.sleep(5)
    driver.close()
    return

# %%
main()

# %%
for i in parse:
    print(i.text)
# Out:
# 합격보상 100만원(주)레인보우로보틱스기업부설연구소 SI/SW 연구인력경력무관, c, 로봇, C++, python
# 합격보상 100만원(주)로그프레소SIEM 기술지원 엔지니어1년 이상, 교육, SQL, DB, Network, 기술지원, 이슈관리
# 합격보상 100만원슈어소프트테크(주)[분석엔진팀] 소스코드 분석엔진 개발 / 전문연구요원 우대경력무관, C#, c, C++, oop, makefile
# 합격보상 100만원(주)플래티어[IDT사업부문] 아틀라시안 & 데브옵스 솔루션 엔지니어 (주임급 이상)2년 이상, python, JIRA, git, SVN, confluence
# 합격보상 100만원(주)이너버스통합보안관리 솔루션 기술 엔지니어(경력)2년 이상, 컨설팅, 네트워크, Linux, 기술지원, dbms, 보안솔루션
# 합격보상 100만원(주)프레인글로벌IT 웹개발자경력무관, Javascript, python, MYSQL, nosql, react, node.js, rdbms, vue, MongoDB
# 합격보상 100만원(주)락플레이스오픈소스 클라우드 컨테이너 솔루션(Redhat OpenShift 기반) 기술지원 엔지니어2년 이상, Linux, 엔지니어, 기술지원, Kubernetes, openshift, container, WEB/WAS
# 합격보상 100만원(주)플래티어[IDT사업부문] 솔루션 엔지니어 (대기업 아틀라시안 운영)4년 이상, python, JIRA, git, SVN, confluence

# %%
driver = webdriver.Chrome()

login(driver, user_id, passwd)
driver.get('https://www.jobplanet.co.kr/job')
# driver.switch_to.frame('mainFrame') # 해당 iframe으로 이동
scroll_all(driver)

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

results = soup.find_all('div', {'class': 'overflow-hidden medium'})
# print(results)

# return results
print(results)
# Out:
# [<div class="overflow-hidden medium"><a class="group z-0 block medium" href="https://www.jobplanet.co.kr/job/search?posting_ids%5B%5D=1288840" rel="noreferrer" target="_blank" title="페이지 이동"><div class="relative w-full overflow-hidden rounded-[12px] border-[1px] border-gray-100 h-[180px]"><img alt="" class="w-full object-cover h-[180px]" height="300" src="https://jpassets.jobplanet.co.kr/production/uploads/job/posting_cover_image/file/116264/cropped_medium_%EB%A0%88%EC%9D%B8%EB%B3%B4%EC%9A%B0%EB%A1%9C%EB%B3%B4%ED%8B%B1%EC%8A%A4%20_1_.png" width="300"/><button class="bookmark absolute right-[16px] top-[16px] z-[9] rounded-[5px] bg-[rgba(0,0,0,0.4)] px-[8px] py-[7px]" title="북마크" type="button"><i class="jf_gray100 block text-[14px] jp-bookmark"></i></button><div class="absolute left-[16px] top-[16px] flex items-center gap-[6px] rounded-[100px] border-[2px] border-[rgba(255,255,255,0.3)] bg-[rgba(36,38,40,0.8)] bg-clip-padding p-[3px_10px]"><img alt="" class="m-[3px_0px] inline-block" h
# ...

# %%
for i in results:
    print(i.text)
# Out:
# 합격보상 100만원(주)레인보우로보틱스기업부설연구소 SI/SW 연구인력경력무관, c, 로봇, C++, python
# 합격보상 100만원(주)로그프레소SIEM 기술지원 엔지니어1년 이상, 교육, SQL, DB, Network, 기술지원, 이슈관리
# 합격보상 100만원슈어소프트테크(주)[분석엔진팀] 소스코드 분석엔진 개발 / 전문연구요원 우대경력무관, C#, c, C++, oop, makefile
# 합격보상 100만원(주)플래티어[IDT사업부문] 아틀라시안 & 데브옵스 솔루션 엔지니어 (주임급 이상)2년 이상, python, JIRA, git, SVN, confluence
# 합격보상 100만원(주)이너버스통합보안관리 솔루션 기술 엔지니어(경력)2년 이상, 컨설팅, 네트워크, Linux, 기술지원, dbms, 보안솔루션
# 합격보상 100만원(주)프레인글로벌IT 웹개발자경력무관, Javascript, python, MYSQL, nosql, react, node.js, rdbms, vue, MongoDB
# 합격보상 100만원(주)락플레이스오픈소스 클라우드 컨테이너 솔루션(Redhat OpenShift 기반) 기술지원 엔지니어2년 이상, Linux, 엔지니어, 기술지원, Kubernetes, openshift, container, WEB/WAS
# 합격보상 100만원(주)플래티어[IDT사업부문] 솔루션 엔지니어 (대기업 아틀라시안 운영)4년 이상, python, JIRA, git, SVN, confluence
# 합격보상 100만원(주)비트센싱[R&D] Functional Safety Engineer경력무관, 자동차, 전자공학, 프로세스 개선, ISO26262, 컴퓨터공학, ASPICE
# 합격보상 100만원(주)레인보우로보틱스기업부설연구소 양팔로봇 SW개발 및 CS인력경력무관, C++, Javascript, python, 로봇개발
# ...

# %%
len(results)
# Out:
# 42
