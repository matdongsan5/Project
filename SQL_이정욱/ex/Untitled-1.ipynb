# %%
import pymysql
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
conn = pymysql.connect(host='172.20.135.53', user='jw',
                        password='1234',
                        db='sql_p3', charset='utf8')

# %%
cur = conn.cursor(pymysql.cursors.DictCursor)
cur.execute('select * from economy_idc_rate')
rows = cur.fetchall() # 모든 데이터를 가져옴-> DataFrame 형태

# %%
rowdf = pd.DataFrame(rows)

# %%
rowdf.head(20)
# Out:
#       시점 국내총생산(명목 원화표시) (십억원) 국내총생산(명목 원화표시) (십억원)_1 국내총생산(명목 원화표시) (십억원)_2  \
# 0   1953                 47.7
# 1   1954                 66.4                   18.6                   39.0
# 2   1955                114.5                   48.1                   72.4
# 3   1956                151.9                   37.4                   32.7
# 4   1957                198.9                   47.1                   31.0
# 5   1958                208.2                    9.3                    4.7
# 6   1959                221.5                   13.4                    6.4
# 7   1960                250.8                   29.2                   13.2
# 8   1961                302.9                   52.2                   20.8
# 9   1962                367.5                   64.6                   21.3
# 10  1963                521.0                  153.5                   41.8
# 11  1964                743.5                  222.5                   42.7
# ...

# %%
rowdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 43 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   시점                             73 non-null     object
#  1   국내총생산(명목 원화표시) (십억원)           73 non-null     object
#  2   국내총생산(명목 원화표시) (십억원)_1         73 non-null     object
#  3   국내총생산(명목 원화표시) (십억원)_2         73 non-null     object
#  4   국내총생산(명목 달러표시) (억달러)           73 non-null     object
#  5   국내총생산(명목 달러표시) (억달러)_1         73 non-null     object
#  6   국내총생산(명목 달러표시) (억달러)_2         73 non-null     object
#  7   국민총소득(명목 원화표시) (십억원)           73 non-null     object
#  8   국민총소득(명목 원화표시) (십억원)_1         73 non-null     object
#  9   국민총소득(명목 원화표시) (십억원)_2         73 non-null     object
#  10  국민총소득(명목 달러표시) (억달러)           73 non-null     object
#  11  국민총소득(명목 달러표시) (억달러)_1         73 non-null     object
# ...

# %%
rowdf = rowdf.drop([71,72])

# %%
rowdf = rowdf.replace('','0')
rowdf = rowdf.astype('float')

# %%
xdata = rowdf['시점'][-20:]
ydata = rowdf['국내총생산(명목 원화표시) (십억원)_2'][-20:]

plt.bar(xdata,ydata)
plt.show()

# %%
cur.execute('select * from both_working')
rows = cur.fetchall() # 모든 데이터를 가져옴-> DataFrame 형태
boDF = pd.DataFrame(rows)

# %%
boDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   시점              9 non-null      int64
#  1   유배우가구 (천가구)     9 non-null      int64
#  2   - 맞벌이가구 (천가구)   9 non-null      int64
#  3   - 맞벌이가구비율 (%)   9 non-null      float64
#  4   - 비맞벌이가구 (천가구)  9 non-null      int64
#  5   - 비맞벌이가구비율 (%)  9 non-null      float64
# dtypes: float64(2), int64(4)
# memory usage: 564.0 bytes

# %%
xdata = rowdf['시점'][-9:]
ydata1 = rowdf['국내총생산(명목 원화표시) (십억원)_2'][-9:]
ydata2 = boDF['- 맞벌이가구 (천가구)']/1000
ydata3 = boDF['- 비맞벌이가구 (천가구)']/1000

# %%
xdata.shape, ydata1.shape, ydata2.shape
# Out:
# ((9,), (9,), (9,))

# %%
plt.bar(xdata,ydata1)
plt.plot(xdata,ydata2, 'ro-')
plt.plot(xdata,ydata3, 'go-')

plt.show()
