# %%
import numpy as np
import matplotlib.pyplot as plt

# 샘플 데이터 (연도별 평균 기온)
years = np.array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010])
temperatures = np.array([14.1, 14.3, 14.2, 14.4, 14.5, 14.6, 14.8, 15.0, 15.1, 15.3, 15.4])

# 1차 회귀 (선형 추세선)
coefficients = np.polyfit(years, temperatures, 1)  # 1차 다항식 피팅 (직선)
trend_line = np.poly1d(coefficients)  # 다항식 객체 생성

# 그래프 그리기
fig, ax = plt.subplots(figsize=(8, 5))
ax.scatter(years, temperatures, label="Actual Temperature", color="blue")  # 원본 데이터
ax.plot(years, trend_line(years), label="Linear Trend Line", color="red", linestyle="--")  # 선형 추세선

# 그래프 설정
ax.set_xlabel("Year")
ax.set_ylabel("Temperature (°C)")
ax.set_title("Annual Temperature Trend")
ax.legend()
plt.show()
